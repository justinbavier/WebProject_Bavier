# %% [markdown]
# ## Creating a Web Data Project with Jupyter Notebooks
# ******
# ###### 1. Read in json file(s) resulting from your work with requests/selenium and beautifulsoup

# %%
# Import necessary packages
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Read in json files and create dataframes
filename = '2017-03-02.StackOverFlow.json'
data = pd.read_json(filename)
filename2 = '2017-03-07.StackOverFlow.json'
data2 = pd.read_json(filename2)

# %% [markdown]
# ###### 2. Clean the data column by column
# - Ensure that addresses (or other text data) are consistent
# - Eliminate string characters from numeric values
# - Exclude redundant data as appropriate

# %%
# Clean up location data to ensure consistency
data2['Salary'].replace({'\n': '' }, regex=True, inplace=True)

# %%
# Show results of cleaning
data2
# Out:
#                                              Employer  \
# 0                                 Northwestern Mutual
# 1                                 Stansberry Research
# 2                              Binny's Beverage Depot
# 3                                               Pendo
# 4                                              Virtru
# 5                                        PrimeRevenue
# 6                                        LunarLincoln
# 7                                                GS&F
# 8                                       ProviderTrust
# 9                                               Kroll
# 10                                          Blackbaud
# 11                                Northwestern Mutual
# 12  Scopus IT (On-site Consulting Project @ Google...
# 13                         Trilogy Education Services
# 14                                ThreatConnect, Inc.
# 15                                  Acuity Scheduling
# 16                                          Wordfence
# 17                                       SemanticBits
# 18                                        Binary Star
# 19                    TransPerfect Translations, Inc.
# 20                         Strata Decision Technology
# 21                                 Altair Engineering
# 22                                 Easy Metrics, Inc.
# 23                                           MailPoet
# 24                                           Sherpany
# 25                                           UC Davis
# 26                                          WayBetter
# 27                                        Instructure
# 28                                    LiveSchool Inc.
# 29                                  Paytronix Systems
# 30                  Global Technology Solutions, Inc.
# 31                                Lucas Systems, Inc.
# 32                                           Complion
# 33                                             Intuit
# 34                                   Crate and Barrel
# 35                                   Crate and Barrel
# 36                                   Crate and Barrel
# 37                                           Mediocre
# 38                                           Mediocre
# 39                                           Mediocre
# 40                                         ThinkCERCA
# 41                                Booz Allen Hamilton
# 42                                           Resin.io
# 43                                           Resin.io
# 44                                   VIDA Diagnostics
# 45                                         Barbaricum
# 46                                 Exigo Office, Inc.
# 47                    Jefferson County Public Schools
# 48                    Jefferson County Public Schools
# 49                                     Service Fusion
#
#                                             Job Title  \
# 0                         Senior IT Security Engineer
# 1                                       Data Engineer
# 2                            Full Stack Web Developer
# 3                                  Front End Engineer
# 4                     Senior Java Developer (Gateway)
# 5                         Sr. Software Engineer- Ruby
# 6                                Mobile App Developer
# 7                        Senior Interactive Developer
# 8   Java Developers at Nashville's Fastest Growing...
# 9                            Senior Software Engineer
# 10          Senior Software Developer - Smart Tuition
# 11                                Full Stack Engineer
# 12  Software Engineer (Full stack with focus on fr...
# 13                         Senior Curriculum Engineer
# 14  UI/UX JavaScript Ninja, Cool Product Company, ...
# 15             Fun loving PHP Developer (100% remote)
# 16                Software Quality Assurance Engineer
# 17                                    DevOps Engineer
# 18                           Full Stack Web Developer
# 19                          Full Stack .NET Developer
# 20                              Senior .NET Developer
# 21                                       QA Developer
# 22                      Intermediate Report Developer
# 23                            PHP/JavaScript Engineer
# 24  Excellence in Web Application Development (Sen...
# 25                             Lead Technical Analyst
# 26                Senior Director, Product Management
# 27                Senior Javascript Software Engineer
# 28  Backend Engineer at Growing Edtech Company in ...
# 29                                     UI/UX Engineer
# 30             IT Secuity Coordinator- St. Louis, MO.
# 31                                  Software Engineer
# 32                   Software Implementation Engineer
# 33                 Software Engineering Group Manager
# 34                     Senior Web Developer – C#/.Net
# 35                         Senior Front End Developer
# 36                       Lead Web Developer - C#/.Net
# 37                                   Support Engineer
# 38                                    DevOps Engineer
# 39         Software Development Engineer (Salesforce)
# 40  Senior Engineer: Ruby on Rails / React in Educ...
# 41                         React.js Developer, Senior
# 42                             Technical Content Lead
# 43                                    DevOps Engineer
# 44              Sr. Software Engineer ( Workstation )
# 45                                  Software Engineer
# 46                                    C#/SQL Engineer
# 47                             Database Administrator
# 48                              Software Developer II
# 49  Vue.js/Javascript/Python Developer - Build NEW...
#
#                    Location        Salary  \
# 0             Milwaukee, WI    Not Listed
# 1             Baltimore, MD    Not Listed
# 2                 Niles, IL    $65k - 85k
# 3               Raleigh, NC    Not Listed
# 4            Washington, DC        Equity
# 5               Atlanta, GA    Not Listed
# 6             Nashville, TN    Not Listed
# 7             Nashville, TN    Not Listed
# 8             Nashville, TN    Not Listed
# 9             Nashville, TN    Not Listed
# 10  Woodbridge Township, NJ    Not Listed
# 11            Milwaukee, WI    Not Listed
# 12             New York, NY  $115k - 160k
# 13             New York, NY    $75k - 80k
# 14            Arlington, VA    Not Listed
# 15             New York, NY   $85k - 110k
# 16       No office location    $75k - 90k
# 17              Herndon, VA    Not Listed
# 18               Exeter, NH    $75k - 85k
# 19             New York, NY   $85k - 110k
# 20              Chicago, IL   $75k - 120k
# 21               Austin, TX    Not Listed
# 22             Issaquah, WA    $80k - 95k
# 23       No office location    Not Listed
# 24       No office location    Not Listed
# 25                Davis, CA    Not Listed
# 26             New York, NY        Equity
# 27       Pleasant Grove, UT    Not Listed
# 28            Nashville, TN    Not Listed
# 29               Newton, MA   $80k - 120k
# 30            St. Louis, MO    Not Listed
# 31              Wexford, PA    Not Listed
# 32            Cleveland, OH        Equity
# 33                             Not Listed
# 34           Northbrook, IL    Not Listed
# 35           Northbrook, IL    Not Listed
# 36           Northbrook, IL    Not Listed
# 37               Dallas, TX    Not Listed
# 38               Dallas, TX    Not Listed
# 39               Dallas, TX        Equity
# 40              Chicago, IL    Not Listed
# 41              Herndon, VA    Not Listed
# 42       No office location    Not Listed
# 43       No office location    Not Listed
# 44                Edina, MN    Not Listed
# 45           Washington, DC    Not Listed
# 46               Dallas, TX    Not Listed
# 47           Louisville, KY   $89k - 124k
# 48           Louisville, KY    $58k - 87k
# 49          Colleyville, TX   $60k - 100k
#
#                                                  Tags       Time
# 0   security   cissp   exchange-server   encryptio...     5h ago
# 1                              sql   etl   sql-server   < 1h ago
# 2        laravel   angularjs   php   javascript   sql   < 1h ago
# 3                                                None   < 1h ago
# 4                                                None   < 1h ago
# 5   docker   javascript   ruby-on-rails   ember.js...     1h ago
# 6                 swift   android   objective-c   ios     3w ago
# 7   html5   sass   node.js   javascript   web-stan...     3w ago
# 8                     c++   java   c#   python   perl     3w ago
# 9               javascript   angular2   web   asp.net     2w ago
# 10                                               None     3h ago
# 11              javascript   java   reactjs   node.js     4h ago
# 12        javascript   css   html   angular2   python     3h ago
# 13   javascript   node.js   mysql   reactjs   mongodb     3h ago
# 14        sass   node.js   dom   angular   javascript     5h ago
# 15                                                php     4h ago
# 16                   php   qa   linux   sqa   testing    22h ago
# 17  amazon-web-services   jenkins   puppet   vagra...     5h ago
# 18            java   javascript   angularjs   reactjs     3h ago
# 19            .net   javascript   angularjs   ravendb     4h ago
# 20  .net   c#   visual-studio-2012   sql-server   ...     7h ago
# 21              java   linux   mysql   eclipse   jira     5h ago
# 22        javascript   postgresql   jaspersoft-studio     2h ago
# 23                         reactjs   php   javascript  yesterday
# 24                             css3   python   django  yesterday
# 25                 project-management   lifecycle   i     4h ago
# 26                  jira   agile   product   consumer     6h ago
# 27     javascript   reactjs   es6   angularjs   redux     4h ago
# 28  amazon-web-services   aws-lambda   amazon-rds-...     3w ago
# 29         scala   jquery   javascript   css3   html5     7h ago
# 30  security   project-management   data-analysis ...  yesterday
# 31                   c#   sql-server   .net   android    15h ago
# 32     javascript   java   c#   dynamics-crm   python    18h ago
# 33                                               None   < 1h ago
# 34           c#   asp.net   mvc   sql-server   jquery  yesterday
# 35  html   css   javascript   jquery   twitter-boo...  yesterday
# 36                     c#   asp.net-mvc   sql   nosql  yesterday
# 37  node.js   mongodb   postgresql   salesforce   ...    20h ago
# 38  node.js   azure   amazon-web-services   mongod...    20h ago
# 39  salesforce   apex-code   visualforce   soql   ...    20h ago
# 40               ruby-on-rails   postgresql   reactjs  yesterday
# 41           reactjs   javascript   java   css   lamp    23h ago
# 42                                               None     4d ago
# 43          docker   continuous-integration   jenkins     4d ago
# 44                        c#   .net   sql   wcf   wpf    22h ago
# 45            java   groovy   linux   oracle   devops  yesterday
# 46                             c#   .net   sql-server  yesterday
# 47  database   dba   sql-server   sql   ssis   sys...     4d ago
# 48  asp.net   c#   web-services   sql   entity-fra...     4d ago
# 49          python   javascript   vue.js   postgresql  yesterday

# %%
# Eliminate string characters from numeric data

# %%
# Show results of cleaning

# %%
# Exclude redundant rows

# %% [markdown]
# ###### 3. Merge dataframes from separate json files as appropriate
# - Find the intersection of two (or more) sets
# - Compare the intersection with the newer set to find 'New Products'
#     - When found, add the starting date
# - Compare the intersection with the older set to find 'Closed Products'
#     - When found, add the closing date
#     - Compare closing date with starting date to find days on market

# %%
# Create the inner merge of the two dataframes

# %%
# Determine the set of 'new products'


# Create the associated dataframe
 
    
# Add the starting date in the dataframe 
# in which the product is first shown

# %%
# Determine the set of 'closed products'


# Create the associated dataframe


# Add the closing date in the dataframe 
# in which the product is last shown


# Find days on market by comparing the starting date 
# with the closing date

# %% [markdown]
# ###### 4. Create visualizations
# - Histogram of Prices
# - Histogram of Days on Market
# - Scatter Diagram of Prices vs Days on Market
# - Pie Chart of New, Like New, Used

# %%
# Create a histogram of Prices


#Temporary Data for Days on Market ... for Scatter Plot Example


# Create a histogram of Days on Market


# Create a Scatter Diagram of Prices vs Days on Market


# Create a Pie Chart of New, Like New, and Used products

# %% [markdown]
# ###### 5. Trends from your data
# - Search for specific brands and offer counts for each
# - Search for product types and offer counts for each
# - For each of the above (and other) give counts for day over day or week over week

# %%
# List the products representing specific brands of your choosing
# for each date provided


# Create a bar chart of products by brand (for the brands chosen)



# List the products of a specific type


# Create a bar chart of products by specific type
# for each date provided

# %%
# Show resulting dataframes of interest

# %%
data
# Out:
#                              Employer  \
# 0               Apex Energy Solutions
# 1                               Veeva
# 2                            Sonatype
# 3                        LunarLincoln
# 4                                GS&F
# 5                           Aculocity
# 6                       ProviderTrust
# 7                             Elastic
# 8                    GX2 Systems, LCC
# 9                    The Farmer's Dog
# 10                  Belvedere Trading
# 11                       HotSchedules
# 12                            Elastic
# 13  Global Technology Solutions, Inc.
# 14                      comScore, Inc
# 15                    LiveSchool Inc.
# 16                             Zyston
# 17                             Zyston
# 18                     BlindData, LLC
# 19                 Dovel Technologies
# 20                             Zyston
# 21                   GrubHub Seamless
# 22                            Tinybop
# 23                Next Gear Solutions
# 24                  Something Digital
# 25                   Creative Commons
# 26                   GrubHub Seamless
# 27                         ASCEND HIT
# 28                            GrubHub
# 29                             Hotjar
# 30                             Hotjar
# 31                             Hotjar
# 32                         Brightcove
# 33                             Hotjar
# 34                             Hotjar
# 35                 PrecisionHawk Inc.
# 36                 PrecisionHawk Inc.
# 37                 PrecisionHawk Inc.
# 38                          Commvault
# 39                 Granbury Solutions
# 40                  Twin Technologies
# 41         APN Software Services, Inc
# 42   UW-Madison, University Marketing
# 43           Johns Hopkins University
# 44         CAMP Systems International
# 45         CAMP Systems International
# 46                       Carbon Black
# 47                         Toptal LLC
# 48                         Toptal LLC
# 49                         Toptal LLC
#
#                                             Job Title            Location  \
# 0                                  Frontend Developer      Zionsville, IN
# 1             Java Engineer, Senior or Principal, CRM      Pleasanton, CA
# 2                     Data Platform Software Engineer  No office location
# 3                                Mobile App Developer       Nashville, TN
# 4                        Senior Interactive Developer       Nashville, TN
# 5                     Software Engineer - ERP Systems   Highland Park, IL
# 6   Java Developers at Nashville's Fastest Growing...       Nashville, TN
# 7   Education Engineer / Technical Trainer - Germa...  No office location
# 8                                       C++ Developer         Chicago, IL
# 9                             Senior Softwar Engineer        Brooklyn, NY
# 10                                       UI Developer         Chicago, IL
# 11                     Software Engineer - Full Stack          Austin, TX
# 12  Education Engineer (Trainer) for Elasticsearch...  No office location
# 13  Business Consultant/ Technical Writer - Lake M...       Lake Mary, FL
# 14  Quality Assurance Engineer - Mobile (Xcode & A...          Reston, VA
# 15  Backend Engineer at Growing Edtech Company in ...       Nashville, TN
# 16                                  Sr. PHP Developer         Atlanta, GA
# 17                                      C++ Developer         Atlanta, GA
# 18           Software Engineer (Java, Python, or C++)        New York, NY
# 19                           Software Engineer - JAVA       Rockville, MD
# 20                                    DevOps Engineer        New York, NY
