# %% [markdown]
# ## Creating a Web Data Project with Jupyter Notebooks
# ******
# ###### 1. Read in json file(s) resulting from your work with requests/selenium and beautifulsoup

# %%
# Import necessary packages
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Read in json files and create dataframes
filename = '2017-03-16.StackOverFlow.json'
data = pd.read_json(filename)

# %% [markdown]
# ###### 2. Clean the data column by column
# - Ensure that addresses (or other text data) are consistent
# - Eliminate string characters from numeric values
# - Exclude redundant data as appropriate

# %%
# Clean up location data to ensure consistency
data['Salary'].replace({'\n': '' }, regex=True, inplace=True)

# %%
# Show results of cleaning
data
# Out:
#                                         Employer  \
# 0                                Railroad19, Inc
# 1                                  ProviderTrust
# 2                                  The Iron Yard
# 3                                   LunarLincoln
# 4                                           GS&F
# 5                                     SSCS, Inc.
# 6                                LiveSchool Inc.
# 7                                          Kroll
# 8                                        Scout24
# 9                     Bonial International Group
# 10                                        Masabi
# 11                                        Masabi
# 12  European Bioinformatics Institute (EMBL-EBI)
# 13                                     FEO Media
# 14                                  Parsons Corp
# 15                                       Medflow
# 16                                       Optiver
# 17                                       Optiver
# 18                           Booz Allen Hamilton
# 19                           Booz Allen Hamilton
# 20                                        GitLab
# 21                                        GitLab
# 22                                       Elastic
# 23                                    Clevertech
# 24                                       Comcast
# 25                                      UC Davis
# 26                                  Rally Health
# 27                                     FlightHub
# 28                         Vista Higher Learning
# 29                                    Legalstart
# 30                                Ally Financial
# 31                                Ally Financial
# 32             Condé Nast International, Digital
# 33                                      UC Davis
# 34                                       Comcast
# 35                                       Comcast
# 36                                    Clevertech
# 37                                   Booking.com
# 38                                  CentralReach
# 39                                        Toptal
# 40                                        Babbel
# 41                                        GitLab
# 42                                      Applause
# 43                                    AssureSign
# 44                           Booz Allen Hamilton
# 45                           Booz Allen Hamilton
# 46                                        Google
# 47                                         AUTO1
# 48                                        Google
# 49                                  Metova, Inc.
#
#                                             Job Title                Location  \
# 0   Senior UI/UX Designer -  Mostly Remote - Fortu...    Englewood Cliffs, NJ
# 1   Seeking Java Developers at Nashville's Best Pl...           Nashville, TN
# 2                   Instructor- Javascript (Fulltime)           Nashville, TN
# 3                                Mobile App Developer           Nashville, TN
# 4                        Senior Interactive Developer           Nashville, TN
# 5                            Senior Software Engineer      No office location
# 6   Backend Engineer at Growing Edtech Company in ...           Nashville, TN
# 7                            Senior Software Engineer           Nashville, TN
# 8   Senior Frontend Developer (m/f) for Germany's ...         Berlin, Germany
# 9     Senior Frontend Developer - Core Platform (m/f)         Berlin, Germany
# 10  Embedded Software Engineer - Help build hardwa...      Greater London, UK
# 11      Java Developer - Help us Build Smarter Cities      Greater London, UK
# 12                              Scientific Programmer             Hinxton, UK
# 13                            Spontaneous Application       Stockholm, Sweden
# 14                 Cybersecurity Software Developer I          Fort Meade, MD
# 15                          Junior Software Developer           Charlotte, NC
# 16                   Trading System Engineer (Python)  Amsterdam, Netherlands
# 17                              C# Software Developer  Amsterdam, Netherlands
# 18                              C++ Developer, Senior          Huntsville, AL
# 19                                  Software Engineer          Huntsville, AL
# 20                       Chef and Ruby Build Engineer      No office location
# 21                                            UX Lead      No office location
# 22   Software Engineer- Data Ingestion Infrastructure      No office location
# 23                                 Video Project Lead      No office location
# 24    Engineer 4 – Software Development & Engineering             Chicago, IL
# 25                          Lead System/Network Admin               Davis, CA
# 26                                    DevOps Engineer       San Francisco, CA
# 27                         Web Developer (Full Stack)    Montreal, QC, Canada
# 28                        Network & Security Engineer              Boston, MA
# 29        Lead Developer - Legaltech leader in France           Paris, France
# 30                               Early Talent Program           Charlotte, NC
# 31                    Technology Early Talent Program           Charlotte, NC
# 32                Software Engineer (Chinese speaker)              London, UK
# 33                             Java Software Engineer               Davis, CA
# 34            Principal Engineer, Product Development              Reston, VA
# 35            Principal Engineer, Product Development              Reston, VA
# 36                             Senior React Developer      No office location
# 37                            MySQL Database Engineer  Amsterdam, Netherlands
# 38                                  Xamarin Developer      No office location
# 39                                     Data Scientist      No office location
# 40        Senior Full-Stack Engineer(Ruby/JavaScript)         Berlin, Germany
# 41                      Sr. Product Marketing Manager      No office location
# 42  Penetration tester / Ethical hacker (Freelance...      No office location
# 43              JavaScript/ C# Developer (Full Stack)             Atlanta, GA
# 44                             .NET Developer, Senior             Atlanta, GA
# 45          .NET/Mobile Application Developer, Senior             Atlanta, GA
# 46     Software Engineer, Google Cloud Platform (GCP)       Mountain View, CA
# 47                          High-flyer Java Developer         Berlin, Germany
# 48                         Software Engineer, YouTube       Mountain View, CA
# 49                                      C++ Developer            Franklin, TN
#
#           Salary                                               Tags       Time
# 0     Not Listed  designer   enterprise   user-interface   wiref...     2h ago
# 1     $75k - 95k                    c++   java   c#   python   perl     3h ago
# 2     Not Listed                     reactjs   javascript   node.js     3d ago
# 3     Not Listed                swift   android   objective-c   ios     4w ago
# 4     Not Listed  html5   sass   node.js   javascript   web-stan...     4w ago
# 5     Not Listed           c#   rest   nosql   domain-driven-design   < 1h ago
# 6     Not Listed  amazon-web-services   aws-lambda   amazon-rds-...     4w ago
# 7     Not Listed  javascript   angular2   sql-server   asp.net   c#     3w ago
# 8     Not Listed      node.js   javascript   angularjs   html   css     2h ago
# 9     Not Listed  javascript   reactjs   html   css   model-view...     2h ago
# 10    £35k - 65k  embedded   embedded-linux   java   c   linux-k...     3h ago
# 11    £45k - 65k                                               java     3h ago
# 12    Not Listed                    python   linux   oop   perl   c     6h ago
# 13    Not Listed              unity3d   tableau   jira   python   r     7h ago
# 14    Not Listed           c++   c   ida   reverse-enginee   fuzzer     3h ago
# 15    Not Listed       oop   .net   version-control   rdbms   agile     6h ago
# 16    €50k - 90k                 linux   python   bamboo   sysadmin     9h ago
# 17    €60k - 90k                                          c#   .net     9h ago
# 18    Not Listed              c++   automated-tests   ada   interop     2d ago
# 19    Not Listed      java   javascript   angularjs   perl   python     2d ago
# 20        Equity  chef   ruby   ruby-on-rails   git   gitlab-omn...     2d ago
# 21    Not Listed  user-experience   open-source   user-interface...     2d ago
# 22    Not Listed     java   jruby   apache-kafka   streaming   ruby     3d ago
# 23    Not Listed                       reactjs   javascript   video     3d ago
# 24    Not Listed              hadoop   ruby-on-rails   web-services    11h ago
# 25    Not Listed                                    windows   linux     2h ago
# 26    Not Listed                                               chef     1h ago
# 27    Not Listed  php   web-developer   software-development   b...     4h ago
# 28    Not Listed                  linux   ruby   python   aws   dns     4h ago
# 29    €40k - 65k        python   react   postgres   django   docker  yesterday
# 30    Not Listed                                               None    21h ago
# 31    Not Listed                             javascript   c#   html    21h ago
# 32    Not Listed                     node.js   reactjs   javascript  yesterday
# 33    Not Listed                            javascript   java   sql     2h ago
# 34    Not Listed                      nosql   design   web-services    11h ago
# 35    Not Listed                              web-services   design    11h ago
# 36    Not Listed                                      react   redux     6d ago
# 37    Not Listed  linux   python   dba   database   mysql   sysa...  yesterday
# 38  $100k - 225k                 xamarin   c#   ios   android   sql     6d ago
# 39    $48k - 96k  r   machine-learning   python   scala   google...     6d ago
# 40    Not Listed  reactjs   javascript   ruby   ruby-on-rails   ...  yesterday
# 41    Not Listed                                               None     6d ago
# 42      €1 - 50k              burpsuite   kali-linux   nmap   owasp     6d ago
# 43    $65k - 90k  c#   typescript   react-redux   web-frontend  ...     2d ago
# 44    Not Listed    asp.net   c#   sql-server   javascript   jquery     2d ago
# 45    Not Listed    asp.net   c#   sql-server   javascript   jquery     2d ago
# 46    Not Listed     java   c++   android   ios   google-app-engine     2h ago
# 47    Not Listed  microservices   spring-boot   rest   aws-lambd...  yesterday
# 48    Not Listed     java   objective-c   python   javascript   c++     2h ago
# 49    Not Listed  c++   c++11   templates   lambda   memory-mana...     2h ago

# %% [markdown]
# ###### 3. Merge dataframes from separate json files as appropriate
# - Find the intersection of two (or more) sets
# - Compare the intersection with the newer set to find 'New Products'
#     - When found, add the starting date
# - Compare the intersection with the older set to find 'Closed Products'
#     - When found, add the closing date
#     - Compare closing date with starting date to find days on market

# %%
# Create the inner merge of the two dataframes

# %%
# Determine the set of 'new products'


# Create the associated dataframe
 
    
# Add the starting date in the dataframe 
# in which the product is first shown

# %%
# Determine the set of 'closed products'


# Create the associated dataframe


# Add the closing date in the dataframe 
# in which the product is last shown


# Find days on market by comparing the starting date 
# with the closing date

# %% [markdown]
# ###### 4. Create visualizations
# - Histogram of Prices
# - Histogram of Days on Market
# - Scatter Diagram of Prices vs Days on Market
# - Pie Chart of New, Like New, Used

# %%
# Create a histogram of Prices


#Temporary Data for Days on Market ... for Scatter Plot Example


# Create a histogram of Days on Market


# Create a Scatter Diagram of Prices vs Days on Market


# Create a Pie Chart of New, Like New, and Used products

# %% [markdown]
# ###### 5. Trends from your data
# - Search for specific brands and offer counts for each
# - Search for product types and offer counts for each
# - For each of the above (and other) give counts for day over day or week over week

# %%
# List the products representing specific brands of your choosing
javaData = data[data['Tags'].str.contains('java ')]

# Create a bar chart of products by brand (for the brands chosen)
javaCount = len(javaData)

objects = ('Java')
colors = ('green')

#y_pos = np.arange(len(objects))
#performance = [10]
#fig = plt.figure(figsize=(15,7))
#plt.bar(y_pos, performance, align='center',alpha=0.5, color=colors)
#plt.xticks(y_pos, objects)
#plt.ylabel('Counts')
#plt.title('Brands')
 
# plt.show()

# List the products of a specific type


# Create a bar chart of products by specific type
# for each date provided

# %%
# Show resulting dataframes of interest

# %%
data
# Out:
#                              Employer  \
# 0               Apex Energy Solutions
# 1                               Veeva
# 2                            Sonatype
# 3                        LunarLincoln
# 4                                GS&F
# 5                           Aculocity
# 6                       ProviderTrust
# 7                             Elastic
# 8                    GX2 Systems, LCC
# 9                    The Farmer's Dog
# 10                  Belvedere Trading
# 11                       HotSchedules
# 12                            Elastic
# 13  Global Technology Solutions, Inc.
# 14                      comScore, Inc
# 15                    LiveSchool Inc.
# 16                             Zyston
# 17                             Zyston
# 18                     BlindData, LLC
# 19                 Dovel Technologies
# 20                             Zyston
# 21                   GrubHub Seamless
# 22                            Tinybop
# 23                Next Gear Solutions
# 24                  Something Digital
# 25                   Creative Commons
# 26                   GrubHub Seamless
# 27                         ASCEND HIT
# 28                            GrubHub
# 29                             Hotjar
# 30                             Hotjar
# 31                             Hotjar
# 32                         Brightcove
# 33                             Hotjar
# 34                             Hotjar
# 35                 PrecisionHawk Inc.
# 36                 PrecisionHawk Inc.
# 37                 PrecisionHawk Inc.
# 38                          Commvault
# 39                 Granbury Solutions
# 40                  Twin Technologies
# 41         APN Software Services, Inc
# 42   UW-Madison, University Marketing
# 43           Johns Hopkins University
# 44         CAMP Systems International
# 45         CAMP Systems International
# 46                       Carbon Black
# 47                         Toptal LLC
# 48                         Toptal LLC
# 49                         Toptal LLC
#
#                                             Job Title            Location  \
# 0                                  Frontend Developer      Zionsville, IN
# 1             Java Engineer, Senior or Principal, CRM      Pleasanton, CA
# 2                     Data Platform Software Engineer  No office location
# 3                                Mobile App Developer       Nashville, TN
# 4                        Senior Interactive Developer       Nashville, TN
# 5                     Software Engineer - ERP Systems   Highland Park, IL
# 6   Java Developers at Nashville's Fastest Growing...       Nashville, TN
# 7   Education Engineer / Technical Trainer - Germa...  No office location
# 8                                       C++ Developer         Chicago, IL
# 9                             Senior Softwar Engineer        Brooklyn, NY
