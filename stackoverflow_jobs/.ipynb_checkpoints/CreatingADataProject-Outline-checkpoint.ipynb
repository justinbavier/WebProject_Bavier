# %% [markdown]
# ## Creating a Web Data Project with Jupyter Notebooks
# ******
# ###### 1. Read in json file(s) resulting from your work with requests/selenium and beautifulsoup

# %%
# Import necessary packages
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Read in json files and create dataframes
filename = '2017-04-03.StackOverFlow.json'
filename2 = '2017-04-04.StackOverFlow.json'
data = pd.read_json(filename)
data2 = pd.read_json(filename2)

# %% [markdown]
# ###### 2. Clean the data column by column
# - Ensure that addresses (or other text data) are consistent
# - Eliminate string characters from numeric values
# - Exclude redundant data as appropriate

# %%
# Clean up location data to ensure consistency
data['Salary'].replace({'\n': '' }, regex=True, inplace=True)
data2['Salary'].replace({'\n': '' }, regex=True, inplace=True)

# %%
# Eliminate any potential duplicates
NoDupsData = data.drop_duplicates()
NoDupsData2 = data2.drop_duplicates()

# %%
# Display first dataframe
NoDupsData
# Out:
#                                               Employer  \
# 0                                                 GS&F
# 1                                             Synopsys
# 2                                        The Iron Yard
# 3                                         LunarLincoln
# 4                                      LiveSchool Inc.
# 5                                           JetSmarter
# 6                                                Kroll
# 7                                            Atlassian
# 8                                             Facebook
# 9                                             Facebook
# 10                                   Integration X A/S
# 11                                   Integration X A/S
# 12                                   Integration X A/S
# 13                                            Facebook
# 14                                            Facebook
# 15                                            Facebook
# 16                                   Fusion Web Clinic
# 17                          Bonial International Group
# 18                                              Cognoa
# 19                                          Lucid, LLC
# 20                                        DaWanda GmbH
# 21                                        DaWanda GmbH
# 22                                            FarmLogs
# 23                                              Zenjob
# 24                                            ad2games
# 25                                    emaratech FZ LLC
# 26                                             StubHub
# 27                                    Crate and Barrel
# 28                                    Crate and Barrel
# 29                                    Crate and Barrel
# ..                                                 ...
# 95                                            Synopsys
# 96                                            Deloitte
# 97                                              Intuit
# 98                                idealo internet GmbH
# 99                                         movingimage
# 100  Springer Science + Business Media Deutschland ...
# 101                                        movingimage
# 102                                        movingimage
# 103                                        movingimage
# 104                                        movingimage
# 105                                  InventoryLab Inc.
# 106                             The Proven Method Inc.
# 107                                         SSCS, Inc.
# 108                                             Masabi
# 109                                             GitLab
# 110                                           Contiamo
# 111                                           BoomTown
# 112  Springer Science + Business Media Deutschland ...
# 113                                            Elastic
# 114                                           Facebook
# 115                                           Facebook
# 116                                           Facebook
# 117                                    Rewards Network
# 118                                       CentralReach
# 119                                             GitLab
# 120                                           Applause
# 121                                         Zalando SE
# 122                                 BROWZZIN Pte. Ltd.
# 123                                          Atlassian
# 124                                        Two Orioles
#
#                                              Job Title  \
# 0                         Senior Interactive Developer
# 1                        Managing Consultant - 12615BR
# 2                    Instructor- Javascript (Fulltime)
# 3                                 Mobile App Developer
# 4    Backend Engineer at Growing Edtech Company in ...
# 5                            Web Application Developer
# 6                             Senior Software Engineer
# 7        Cloud Architect - JIRA (Java / ReactJS / AWS)
# 8                           Developer Support Engineer
# 9                   Partner Engineering Manager, Games
# 10                             Senior System developer
# 11                          Senior Front-end developer
# 12                                Full stack developer
# 13                                 Production Engineer
# 14                                 Production Engineer
# 15                          Solutions Engineer, Mobile
# 16                        Server Administrator (Linux)
# 17     Senior Frontend Developer - Core Platform (m/f)
# 18                                  Lead iOS Developer
# 19                                    TechOps Engineer
# 20            QA Engineer (f/m) - Marketplace platform
# 21   Software Engineer Ruby (f/m) - Marketplace pla...
# 22                                   Android Developer
# 23                      React Frontend Developer (m/f)
# 24   (Senior) Ruby on Rails Engineer (m/f) for ad2g...
# 25                                     DevOps Engineer
# 26                                     Designer, Email
# 27                          Senior Front End Developer
# 112          Berlin, Deutschland      Not Listed
# 113           No office location      Not Listed
# 114                   London, UK      Not Listed
# 115                   London, UK      Not Listed
# 116                   London, UK      Not Listed
# 117                  Chicago, IL      Not Listed
# 118           No office location  $100k - 225k\n
# 119           No office location      Not Listed
# 120           No office location      €1 - 50k\n
# 121              Berlin, Germany      Not Listed
# 122                    Singapore    $30k - 60k\n
# 123            Sydney, Australia      Not Listed
# 124                 New York, NY   $80k - 120k\n
#
#                                                   Tags       Time
# 0    html5   sass   node.js   javascript   web-stan...     2w ago
# 1                                      security   sdlc     5d ago
# 2                       reactjs   javascript   node.js     3w ago
# 3                  swift   android   objective-c   ios     2w ago
# 4    amazon-web-services   aws-lambda   amazon-rds-...     2w ago
# 5     user-experience   css   html5   javascript   sql   < 1h ago
# 6    javascript   angular2   sql-server   asp.net   c#     1w ago
# 7                                 saas   java   design     1h ago
# 8                      java   javascript   objective-c     2h ago
# 9         javascript   objective-c   php   java   .net     2h ago
# 10                  java   mysql   xquery   javascript    11h ago
# 11                             javascript   css   html    11h ago
# 12            javascript   java   mysql   html   junit    11h ago
# 13                        unix   tcp   ip   lamp   cdn     3h ago
# 14                    unix   tcp   lamp   cdn   apache     3h ago
# 15                tcp   http   html   javascript   css     3h ago
# 16   server-administration   linux   servers   syst...     3h ago
# 17             css   javascript   html   reactjs   sql     3h ago
# 18                   ruby-on-rails   ios   objective-c   < 1h ago
# 19           javascript   css   python   node.js   api     2h ago
# 20   selenium-webdriver   jira   testlink   appium ...     4h ago
# 21   ruby   ruby-on-rails   sinatra   software   agile     4h ago
# 22                             android   java   mobile     2h ago
# 23   javascript   reactjs   single-page-application...     5h ago
# 24   ruby   ruby-on-rails   docker   go   amazon-we...     6h ago
# 25   jenkins   docker   scripting   bamboo   conflu...    13h ago
# 26                                            designer   < 1h ago
# 27   html   css   javascript   jquery   twitter-boo...     4h ago
# 28            c#   asp.net   mvc   sql-server   jquery     4h ago
# 29                      c#   asp.net-mvc   sql   nosql     4h ago
# ..                                                 ...        ...
# 95           project-management   sql   ruby   c   c++     5d ago
# 96                  .net   amazon-web-services   cloud     5d ago
# 97     cloud   highvolumescaling   amazon-web-services     5h ago
# 98                                        java   agile     3d ago
# 99   azure   cloud   architecture   video   aws-lambda     3d ago
# 100       java   cloud   ruby   microservices   python     4d ago
# 101      php   jenkins   symfony-2.1   mysql   mongodb     3d ago
# 102  angularjs   javascript   typescript   html5   ...     3d ago
# 103               php   mysql   nosql   mongodb   rest     3d ago
# 104       docker   cloud   php   jenkins   performance     3d ago
# 105  c#   amazon-web-services   java-script   mobil...     2w ago
# 106          ios   cocoa   objective-c   swift   xcode     6d ago
# 107           c#   rest   nosql   domain-driven-design     3w ago
# 108      amazon-web-services   puppet   docker   linux     4d ago
# 109  chef   ruby   ruby-on-rails   git   gitlab-omn...     3w ago
# 110                     java   scala   apache   hadoop     4d ago
# 111              c#   clojure   .net   varnish   scala     1w ago
# 112         tdd   angular2   html5   javascript   css3     4d ago
# 113     java   jruby   apache-kafka   streaming   ruby     3w ago
# 114              php   javascript   html   xhtml   css     5d ago
# 115                          c++   c   php   java   c#     5d ago
# 116                          objective-c   c++   cocoa     5d ago
# 117                      scala   java   c#   git   oop     3d ago
# 118                 xamarin   c#   ios   android   sql     3w ago
# 119                                               None     3w ago
# 120              burpsuite   kali-linux   nmap   owasp     3w ago
# 121    postgresql   cassandra   python   go   sysadmin     5d ago
# 122    javascript   reactjs   angularjs   python   php     3d ago
# 123                   html   javascript   design   css     4d ago
# 124  assembly   c   h.264   video-encoding   image-...  yesterday
#
# [125 rows x 6 columns]

# %%
# Display second dataframe
NoDupsData2
# Out:
#                                Employer  \
# 0                         Genscape, Inc
# 1                              Synopsys
# 2                         The Iron Yard
# 3                       ERF Medien e.V.
# 4                          LunarLincoln
# 5                                  GS&F
# 6                                Ansira
# 7              Booz Allen Hamilton, Inc
# 8                                 GLOBO
# 9              Booz Allen Hamilton, Inc
# 10             Booz Allen Hamilton, Inc
# 11             Booz Allen Hamilton, Inc
# 12             Booz Allen Hamilton, Inc
# 13             Booz Allen Hamilton, Inc
# 14             Booz Allen Hamilton, Inc
# 15             Booz Allen Hamilton, Inc
# 16             Booz Allen Hamilton, Inc
# 17             Booz Allen Hamilton, Inc
# 18                      LiveSchool Inc.
# 19   Ben Kinney Companies Tech Division
# 20                             HeavenHR
# 21   Ben Kinney Companies Tech Division
# 22    Global Technology Solutions, Inc.
# 23                               NextVR
# 24                                Kroll
# 25                        Sevatec, Inc.
# 26                               Bynder
# 27                                 eBay
# 28                           Clevertech
# 29                           Clevertech
# ..                                  ...
# 95                             Clearbit
# 96                             FarmLogs
# 97                           Lucid, LLC
# 98                            GreenSync
# 99                      JRD Systems Inc
# 100                      Healthesystems
# 101                           Staff.com
# 102                     Lucida's Client
# 103                InFlight Corporation
# 104                               Skuid
# 105                       The Iron Yard
# 106                 Finivation Software
# 107                     AudiologyDesign
# 108                      Healthesystems
# 109                             Comcast
# 110                             Comcast
# 111                             Comcast
# 112                            Sonatype
# 113                  WWF Washington, DC
# 114                  CNM Marketing Inc.
# 115                 Allied Health Media
# 116                         Time Doctor
# 117                            Deloitte
# 118                                Cin7
# 119                               Kopis
# 120                                 Olo
# 121                            Synopsys
# 122                        Market Track
# 123                        Market Track
# 124                          Clevertech
#
#                                              Job Title  \
# 0    Senior Software Engineer - Applications and In...
# 1                        Managing Consultant - 12615BR
# 2                    Instructor- Javascript (Fulltime)
# 3                              PHP-Webentwickler (m/w)
# 4                                 Mobile App Developer
# 5                         Senior Interactive Developer
# 6                                 ColdFusion Developer
# 7                            Software Engineer, Senior
# 8                                      DevOps Engineer
# 9                                    Software Engineer
# 10                                Full Stack Developer
# 11                         Algorithm Developer, Senior
# 12                                    Reverse Engineer
# 13                                   Software Engineer
# 14                                   Software Engineer
# 15                                      .NET Developer
# 16                              Software Engineer, Mid
# 17                                    Drupal Developer
# 18   Backend Engineer at Growing Edtech Company in ...
# 19                                                 CTO
# 20                       (Senior) Java Developer (m/f)
# 21                      Senior Ruby on Rails Developer
# 22        Application Engineer - Lead    St. Louis, MO
# 23                                  Frontend Developer
# 24                            Senior Software Engineer
# 25                  UX/UI Mobile Web Designer - REMOTE
# 26                              Senior DevOps Engineer
# 118             Redmond, WA    $90k - 110k\n
# 119          Greenville, SC     $70k - 90k\n
# 120            New York, NY       Not Listed
# 121         Bloomington, IN       Not Listed
# 122         Jersey City, NJ       Not Listed
# 123            New York, NY       Not Listed
# 124            New York, NY       Not Listed
#
#                                                   Tags       Time
# 0    cloud   azure   amazon-web-services   tibco   ...     1h ago
# 1                                      security   sdlc     6d ago
# 2                       reactjs   javascript   node.js     3w ago
# 3                   php   mysql   phpstorm   git   cvs   < 1h ago
# 4                  swift   android   objective-c   ios     2w ago
# 5    html5   sass   node.js   javascript   web-stan...     2w ago
# 6                                           coldfusion     1h ago
# 7                          reactjs   javascript   java     2h ago
# 8    devops   amazon-web-services   mysql   redis  ...   < 1h ago
# 9                                  sql   c#   security     3h ago
# 10                         javascript   python   agile     3h ago
# 11                  algorithm   machine-learning   oop     3h ago
# 12                                    c++   c   python     3h ago
# 13                                 java   design   c++     3h ago
# 14             agile   continuous-integration   design     3h ago
# 15                                   agile   .net   c#     3h ago
# 16                                    c   java   cloud     3h ago
# 17                              php   angularjs   lamp     3h ago
# 18   amazon-web-services   aws-lambda   amazon-rds-...     3w ago
# 19    css3   html5   javascript   ruby-on-rails   ruby   < 1h ago
# 20         java   spring   hibernate   java-7   java-8     1h ago
# 21    ruby   ruby-on-rails   css3   html5   javascript   < 1h ago
# 22   node.js   java   continuous-integration   reac...     2h ago
# 23           javascript   html   css   angularjs   git   < 1h ago
# 24   javascript   angular2   sql-server   asp.net   c#     1w ago
# 25   user-experience   user-interface   adobe   508...     4h ago
# 26   cloud   python   devops   linux   amazon-web-s...     2h ago
# 27                            2   years   of   working   < 1h ago
# 28                                reactjs   javascript    21h ago
# 29   reactjs   javascript   clojure   redux   react...    21h ago
# ..                                                 ...        ...
# 95                                                None     3h ago
# 96                             android   java   mobile  yesterday
# 97           javascript   css   python   node.js   api  yesterday
# 98   ruby-on-rails   javascript   ruby   coffeescri...  yesterday
# 99         j2ee   spring   angularjs   junit   mockito  yesterday
# 100              selenium   qa   java   hp-uft   agile    21h ago
# 101                     objective-c   qt   applescript     2w ago
# 102  java   machine-learning   elasticsearch   luce...     2d ago
# 103  backbone.js   javascript   user-interface   ht...     2w ago
# 104      sql   nosql   automated-tests   qa   selenium     2w ago
# 105         reactjs   html   javascript   css   jquery     4d ago
# 106             .net   c#   javascript   html5   mysql    14h ago
# 107            php   mysql   node.js   nginx   cakephp     2w ago
# 108  css   javascript   html   content-management-s...    21h ago
# 109                                  osx   c++   linux    10h ago
# 110                           hadoop   agile   bigdata    10h ago
# 111                            java   hadoop   java-ee    10h ago
# 112  hadoop   etl   mapreduce   elasticsearch   sof...     2w ago
# 113                   ssms   ssrs   ssis   ssas   oltp  yesterday
# 114         drupal   twitter-bootstrap   twig   jquery     2w ago
# 115                 php   cakephp   html5   javascript     2w ago
# 116                                                php     2w ago
# 117                                               None     5d ago
# 118                                               this     4h ago
# 119       c#   html   javascript   css   visual-studio     4d ago
# 120           c#   f#   asp.net   javascript   xamarin    20h ago
# 121          project-management   sql   ruby   c   c++     6d ago
# 122    windows   a+   certification   tcpip   sysadmin    20h ago
# 123                                iptv   windows   qa    20h ago
# 124                                               java    20h ago
#
# [125 rows x 6 columns]

# %% [markdown]
# ***Questions of Interest***
#  1. What language/skill is in the highest demand among employers? **Will Examine for Project**
#  2. Where are most development jobs located? **Will Examine for Project**
#  3. What language/skill brings in the highest salary? Might be tough to do since many job offerings do not list a salary.
#  4. What companies are most frequently posting jobs?
#  5. What jobs have the quickest turnover rate?
#  6. What kind of jobs stay posted for the longest period of time?

# %% [markdown]
# ###### 3. Merge dataframes from separate json files as appropriate
# - Find the intersection of two (or more) sets
# - Compare the intersection with the newer set to find 'New Products'
#     - When found, add the starting date
# - Compare the intersection with the older set to find 'Closed Products'
#     - When found, add the closing date
#     - Compare closing date with starting date to find days on market

# %%
# Create the inner merge of the two dataframes
dataInnerMerge = pd.merge(NoDupsData, NoDupsData2, \
                          on=['Employer', 'Job Title'],\
                          how='inner')

# %%
# Determine the set of 'new products'
dataInnerMerge

# Create the associated dataframe
 
    
# Add the starting date in the dataframe 
# in which the product is first shown
# Out:
#                       Employer  \
# 0                         GS&F
# 1                     Synopsys
# 2                The Iron Yard
# 3                 LunarLincoln
# 4              LiveSchool Inc.
# 5                        Kroll
# 6                    Atlassian
# 7                     Facebook
# 8                     Facebook
# 9            Integration X A/S
# 10           Integration X A/S
# 11           Integration X A/S
# 12                    Facebook
# 13                    Facebook
# 14                    Facebook
# 15                    Facebook
# 16                    Facebook
# 17           Fusion Web Clinic
# 18  Bonial International Group
# 19                  Lucid, LLC
# 20                DaWanda GmbH
# 21                DaWanda GmbH
# 22                    FarmLogs
# 23                      Zenjob
# 24                    ad2games
# 25            emaratech FZ LLC
# 26            Crate and Barrel
# 27            Crate and Barrel
# 28            Crate and Barrel
# 29          WWF Washington, DC
# ..                         ...
# 35             Railroad19, Inc
# 36             Lucida's Client
# 37                      Toptal
# 38                      Toptal
# 39                  BrainJocks
# 40              Brave Software
# 41                      YouGov
# 42              Reconfigure.io
# 43            Statement Campus
# 44            Statement Campus
# 45            Statement Campus
# 46            Statement Campus
# 47                      RateIt
# 48                      GitLab
# 49                  Clevertech
# 50                  Clevertech
# 51                Metova, Inc.
# 52                Metova, Inc.
# 53               The Iron Yard
# 54                   Staff.com
# 55                       Skuid
# 56        InFlight Corporation
# 57             AudiologyDesign
# 58                    Deloitte
# 59                       Kopis
# 60                    Sonatype
# 61          CNM Marketing Inc.
# 62         Allied Health Media
# 63                 Time Doctor
# 64                    Synopsys
#
#                                             Job Title  \
# 0                        Senior Interactive Developer
# 1                       Managing Consultant - 12615BR
# 2                   Instructor- Javascript (Fulltime)
# 3                                Mobile App Developer
# 4   Backend Engineer at Growing Edtech Company in ...
# 5                            Senior Software Engineer
# 6       Cloud Architect - JIRA (Java / ReactJS / AWS)
# 7                          Developer Support Engineer
# 8                  Partner Engineering Manager, Games
# 9                             Senior System developer
# 10                         Senior Front-end developer
# 11                               Full stack developer
# 12                                Production Engineer
# 13                                Production Engineer
# 14                                Production Engineer
# 15                                Production Engineer
# 16                         Solutions Engineer, Mobile
# 17                       Server Administrator (Linux)
# 18    Senior Frontend Developer - Core Platform (m/f)
# 19                                   TechOps Engineer
# 20           QA Engineer (f/m) - Marketplace platform
# 21  Software Engineer Ruby (f/m) - Marketplace pla...
# 22                                  Android Developer
# 23                     React Frontend Developer (m/f)
# 24  (Senior) Ruby on Rails Engineer (m/f) for ad2g...
# 25                                    DevOps Engineer
# 26                         Senior Front End Developer
# 27                     Senior Web Developer – C#/.Net
# 59               Greenville, SC     $70k - 90k\n
# 60           No office location       Not Listed
# 61           No office location       Not Listed
# 62           No office location       Not Listed
# 63           No office location       Not Listed
# 64              Bloomington, IN       Not Listed
#
#                                                Tags_x   Time_x  \
# 0   html5   sass   node.js   javascript   web-stan...   2w ago
# 1                                     security   sdlc   5d ago
# 2                      reactjs   javascript   node.js   3w ago
# 3                 swift   android   objective-c   ios   2w ago
# 4   amazon-web-services   aws-lambda   amazon-rds-...   2w ago
# 5   javascript   angular2   sql-server   asp.net   c#   1w ago
# 6                                saas   java   design   1h ago
# 7                     java   javascript   objective-c   2h ago
# 8        javascript   objective-c   php   java   .net   2h ago
# 9                  java   mysql   xquery   javascript  11h ago
# 10                            javascript   css   html  11h ago
# 11           javascript   java   mysql   html   junit  11h ago
# 12                       unix   tcp   ip   lamp   cdn   3h ago
# 13                       unix   tcp   ip   lamp   cdn   3h ago
# 14                   unix   tcp   lamp   cdn   apache   3h ago
# 15                   unix   tcp   lamp   cdn   apache   3h ago
# 16               tcp   http   html   javascript   css   3h ago
# 17  server-administration   linux   servers   syst...   3h ago
# 18            css   javascript   html   reactjs   sql   3h ago
# 19          javascript   css   python   node.js   api   2h ago
# 20  selenium-webdriver   jira   testlink   appium ...   4h ago
# 21  ruby   ruby-on-rails   sinatra   software   agile   4h ago
# 22                            android   java   mobile   2h ago
# 23  javascript   reactjs   single-page-application...   5h ago
# 24  ruby   ruby-on-rails   docker   go   amazon-we...   6h ago
# 25  jenkins   docker   scripting   bamboo   conflu...  13h ago
# 26  html   css   javascript   jquery   twitter-boo...   4h ago
# 27           c#   asp.net   mvc   sql-server   jquery   4h ago
# 28                     c#   asp.net-mvc   sql   nosql   4h ago
# 29                   ssms   ssrs   ssis   ssas   oltp   3h ago
# ..                                                ...      ...
# 35  javascript   frontend   angular2   typescript ...   6d ago
# 36  java   machine-learning   elasticsearch   luce...  16h ago
# 37  ruby-on-rails   postgresql   elasticsearch   r...   5d ago
# 38  r   machine-learning   python   scala   google...   5d ago
# 39   frontend   windows   sitecore   css   javascript   2d ago
# 40                  android   testing   java   senior   5d ago
# 41  python-2.7   python-3.x   mongodb   postgresql...   5d ago
# 42        haskell   go   compiler-construction   fpga   6d ago
# 43                            android   mobile   java   6d ago
# 44                   javascript   node.js   angularjs   6d ago
# 45                           java   python   c++   go   6d ago
# 46                                java   python   c++   6d ago
# 47   c#   sql-server   angularjs   backbone.js   .net   1w ago
# 48                                               None   1w ago
# 49  javascript   architecture   python   c++   clo...   1w ago
# 50                               reactjs   javascript   1w ago
# 51  c++   c++11   templates   lambda   memory-mana...   3w ago
# 52  android   java   material-design   android-fra...   3w ago
# 53         reactjs   html   javascript   css   jquery   3d ago
# 54                     objective-c   qt   applescript   2w ago
# 55      sql   nosql   automated-tests   qa   selenium   1w ago
# 56  backbone.js   javascript   user-interface   ht...   2w ago
# 57            php   mysql   node.js   nginx   cakephp   2w ago
# 58                                               None   4d ago
# 59       c#   html   javascript   css   visual-studio   3d ago
# 60  hadoop   etl   mapreduce   elasticsearch   sof...   2w ago
# 61         drupal   twitter-bootstrap   twig   jquery   2w ago
# 62                 php   cakephp   html5   javascript   2w ago
# 63                                                php   2w ago
# 64          project-management   sql   ruby   c   c++   5d ago
#
#                      Location_y         Salary_y  \
# 0                 Nashville, TN       Not Listed
# 1                 Nashville, TN       Not Listed
# 2                 Nashville, TN       Not Listed
# 3                 Nashville, TN       Not Listed
# 4                 Nashville, TN       Not Listed
# 5                 Nashville, TN       Not Listed
# 6             Sydney, Australia       Not Listed
# 7               Dublin, Ireland       Not Listed
# 8                    London, UK       Not Listed
# 9            No office location       Not Listed
# 10           No office location       Not Listed
# 11           No office location       Not Listed
# 12              Dublin, Ireland       Not Listed
# 13                   London, UK       Not Listed
# 14              Dublin, Ireland       Not Listed
# 15                   London, UK       Not Listed
# 16                   London, UK       Not Listed
# 17               Greenville, SC       Not Listed
# 18              Berlin, Germany       Not Listed
# 19              New Orleans, LA       Not Listed
# 20          Berlin, Deutschland       Not Listed
# 21          Berlin, Deutschland       Not Listed
# 22                Ann Arbor, MI       Not Listed
# 23              Berlin, Germany       Not Listed
# 24              Berlin, Germany       Not Listed
# 25  Dubai, United Arab Emirates     $40k - 48k\n
# 26               Northbrook, IL       Not Listed
# 27               Northbrook, IL       Not Listed
# 28               Northbrook, IL       Not Listed
# 29               Washington, DC       Not Listed
# ..                          ...              ...
# 35           No office location       Not Listed
# 36         Melbourne, Australia  A$140k - 180k\n
# 37           No office location     $48k - 96k\n
# 38           No office location     $48k - 96k\n
# 39                 Kennesaw, GA       Not Listed
# 40           No office location           Equity
# 41           No office location       Not Listed
# 42           No office location       Not Listed
# 43           No office location       Not Listed
# 44           No office location       Not Listed
# 45           No office location       Not Listed
# 46           No office location       Not Listed
# 47           No office location       Not Listed
# 48           No office location       Not Listed
# 49           No office location       Not Listed
# 50           No office location       Not Listed
# 51                 Franklin, TN       Not Listed
# 52                 Franklin, TN       Not Listed
# 53                  Atlanta, GA       Not Listed
# 54           No office location       Not Listed
# 55              Chattanooga, TN       Not Listed
# 56           No office location     $60k - 85k\n
# 57           No office location     $70k - 80k\n
# 58                  Atlanta, GA       Not Listed
# 59               Greenville, SC     $70k - 90k\n
# 60           No office location       Not Listed
# 61           No office location       Not Listed
# 62           No office location       Not Listed
# 63           No office location       Not Listed
# 64              Bloomington, IN       Not Listed
#
#                                                Tags_y     Time_y
# 0   html5   sass   node.js   javascript   web-stan...     2w ago
# 1                                     security   sdlc     6d ago
# 2                      reactjs   javascript   node.js     3w ago
# 3                 swift   android   objective-c   ios     2w ago
# 4   amazon-web-services   aws-lambda   amazon-rds-...     3w ago
# 5   javascript   angular2   sql-server   asp.net   c#     1w ago
# 6                                saas   java   design  yesterday
# 7                     java   javascript   objective-c  yesterday
# 8        javascript   objective-c   php   java   .net  yesterday
# 9                  java   mysql   xquery   javascript  yesterday
# 10                            javascript   css   html  yesterday
# 11           javascript   java   mysql   html   junit  yesterday
# 12                       unix   tcp   ip   lamp   cdn  yesterday
# 13                   unix   tcp   lamp   cdn   apache  yesterday
# 14                       unix   tcp   ip   lamp   cdn  yesterday
# 15                   unix   tcp   lamp   cdn   apache  yesterday
# 16               tcp   http   html   javascript   css  yesterday
# 17  server-administration   linux   servers   syst...  yesterday
# 18            css   javascript   html   reactjs   sql  yesterday
# 19          javascript   css   python   node.js   api  yesterday
# 20  selenium-webdriver   jira   testlink   appium ...  yesterday
# 21  ruby   ruby-on-rails   sinatra   software   agile  yesterday
# 22                            android   java   mobile  yesterday
# 23  javascript   reactjs   single-page-application...  yesterday
# 24  ruby   ruby-on-rails   docker   go   amazon-we...  yesterday
# 25  jenkins   docker   scripting   bamboo   conflu...  yesterday
# 26  html   css   javascript   jquery   twitter-boo...  yesterday
# 27           c#   asp.net   mvc   sql-server   jquery  yesterday
# 28                     c#   asp.net-mvc   sql   nosql  yesterday
# 29                   ssms   ssrs   ssis   ssas   oltp  yesterday
# ..                                                ...        ...
# 35  javascript   frontend   angular2   typescript ...     1w ago
# 36  java   machine-learning   elasticsearch   luce...     2d ago
# 37  ruby-on-rails   postgresql   elasticsearch   r...     6d ago
# 38  r   machine-learning   python   scala   google...     6d ago
# 39   frontend   windows   sitecore   css   javascript     3d ago
# 40                  android   testing   java   senior     6d ago
# 41  python-2.7   python-3.x   mongodb   postgresql...     6d ago
# 42        haskell   go   compiler-construction   fpga     1w ago
# 43                            android   mobile   java     1w ago
# 44                   javascript   node.js   angularjs     1w ago
# 45                           java   python   c++   go     1w ago
# 46                                java   python   c++     1w ago
# 47   c#   sql-server   angularjs   backbone.js   .net     1w ago
# 48                                               None     1w ago
# 49  reactjs   javascript   clojure   redux   react...    21h ago
# 50                               reactjs   javascript    21h ago
# 51  c++   c++11   templates   lambda   memory-mana...     3w ago
# 52  android   java   material-design   android-fra...     3w ago
# 53         reactjs   html   javascript   css   jquery     4d ago
# 54                     objective-c   qt   applescript     2w ago
# 55      sql   nosql   automated-tests   qa   selenium     2w ago
# 56  backbone.js   javascript   user-interface   ht...     2w ago
# 57            php   mysql   node.js   nginx   cakephp     2w ago
# 58                                               None     5d ago
# 59       c#   html   javascript   css   visual-studio     4d ago
# 60  hadoop   etl   mapreduce   elasticsearch   sof...     2w ago
# 61         drupal   twitter-bootstrap   twig   jquery     2w ago
# 62                 php   cakephp   html5   javascript     2w ago
# 63                                                php     2w ago
# 64          project-management   sql   ruby   c   c++     6d ago
#
# [65 rows x 10 columns]

# %%
# Determine the set of 'closed products'


# Create the associated dataframe


# Add the closing date in the dataframe 
# in which the product is last shown


# Find days on market by comparing the starting date 
# with the closing date

# %% [markdown]
# ###### 4. Create visualizations
# - Histogram of Prices
# - Histogram of Days on Market
# - Scatter Diagram of Prices vs Days on Market
# - Pie Chart of New, Like New, Used

# %%
# Create a histogram of Prices


#Temporary Data for Days on Market ... for Scatter Plot Example


# Create a histogram of Days on Market


# Create a Scatter Diagram of Prices vs Days on Market


# Create a Pie Chart of New, Like New, and Used products

# %% [markdown]
# ###### 5. Trends from your data
# - Search for specific brands and offer counts for each
# - Search for product types and offer counts for each
# - For each of the above (and other) give counts for day over day or week over week

# %%
# List the products representing specific brands of your choosing
javaData = data[data['Tags'].str.contains('java ')]
phpData = data[data['Tags'].str.contains('php ')]

# Create a bar chart of products by brand (for the brands chosen)
javaCount = len(javaData)
phpCount = len(phpData)

objects = ('Java', '', 'PHP', '')
colors = ('green')

y_pos = np.arange(len(objects))
performance = [javaCount, 0, phpData, 0]
fig = plt.figure(figsize=(15,7))
plt.bar(y_pos, performance, align='center',alpha=0.5, color=colors)
plt.xticks(y_pos, objects)
plt.ylabel('Counts')
plt.title('Brands')
 
plt.show()

# List the products of a specific type


# Create a bar chart of products by specific type
# for each date provided
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-df580be97445> in <module>()
#      13 performance = [javaCount, 0, phpData, 0]
#      14 fig = plt.figure(figsize=(15,7))
# ---> 15 plt.bar(y_pos, performance, align='center',alpha=0.5, color=colors)
#      16 plt.xticks(y_pos, objects)
#      17 plt.ylabel('Counts')
#
# C:\Users\jbavi\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2648     try:
#    2649         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2650                      **kwargs)
#    2651     finally:
#    2652         ax.hold(washold)
#
# C:\Users\jbavi\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
#    1819         pre_doc = inner.__doc__
#    1820         if pre_doc is None:
#
# C:\Users\jbavi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2074         args = zip(left, bottom, width, height, color, edgecolor, linewidth)
#    2075         for l, b, w, h, c, e, lw in args:
# -> 2076             if h < 0:
#    2077                 b += h
#    2078                 h = abs(h)
#
# C:\Users\jbavi\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#     890         raise ValueError("The truth value of a {0} is ambiguous. "
#     891                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 892                          .format(self.__class__.__name__))
#     893
#     894     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Show resulting dataframes of interest

# %%
data
# Out:
#                              Employer  \
# 0               Apex Energy Solutions
# 1                               Veeva
# 2                            Sonatype
# 3                        LunarLincoln
# 4                                GS&F
# 5                           Aculocity
# 6                       ProviderTrust
# 7                             Elastic
# 8                    GX2 Systems, LCC
# 9                    The Farmer's Dog
# 10                  Belvedere Trading
# 11                       HotSchedules
# 12                            Elastic
# 13  Global Technology Solutions, Inc.
# 14                      comScore, Inc
# 15                    LiveSchool Inc.
# 16                             Zyston
# 17                             Zyston
# 18                     BlindData, LLC
# 19                 Dovel Technologies
# 20                             Zyston
# 21                   GrubHub Seamless
# 22                            Tinybop
# 23                Next Gear Solutions
# 24                  Something Digital
# 25                   Creative Commons
# 26                   GrubHub Seamless
# 27                         ASCEND HIT
# 28                            GrubHub
# 29                             Hotjar
# 30                             Hotjar
# 31                             Hotjar
# 32                         Brightcove
# 33                             Hotjar
# 34                             Hotjar
# 35                 PrecisionHawk Inc.
# 36                 PrecisionHawk Inc.
# 37                 PrecisionHawk Inc.
# 38                          Commvault
# 39                 Granbury Solutions
# 40                  Twin Technologies
# 41         APN Software Services, Inc
# 42   UW-Madison, University Marketing
# 43           Johns Hopkins University
# 44         CAMP Systems International
# 45         CAMP Systems International
# 46                       Carbon Black
# 47                         Toptal LLC
# 48                         Toptal LLC
# 49                         Toptal LLC
#
#                                             Job Title            Location  \
# 0                                  Frontend Developer      Zionsville, IN
# 1             Java Engineer, Senior or Principal, CRM      Pleasanton, CA
# 2                     Data Platform Software Engineer  No office location
# 3                                Mobile App Developer       Nashville, TN
# 4                        Senior Interactive Developer       Nashville, TN
# 5                     Software Engineer - ERP Systems   Highland Park, IL
# 6   Java Developers at Nashville's Fastest Growing...       Nashville, TN
# 7   Education Engineer / Technical Trainer - Germa...  No office location
# 8                                       C++ Developer         Chicago, IL
# 9                             Senior Softwar Engineer        Brooklyn, NY
# 10                                       UI Developer         Chicago, IL
# 11                     Software Engineer - Full Stack          Austin, TX
# 12  Education Engineer (Trainer) for Elasticsearch...  No office location
# 13  Business Consultant/ Technical Writer - Lake M...       Lake Mary, FL
