# %% [markdown]
# ## Creating a Web Data Project with Jupyter Notebooks
# ******
# ###### 1. Read in json file(s) resulting from your work with requests/selenium and beautifulsoup

# %%
# Import necessary packages
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# Read in json files and create dataframes
filename = '2017-02-27.Sweetwater.json'
data = pd.read_json(filename)
filename2 = '2017-03-01.Sweetwater.json'
data2 = pd.read_json(filename2)

# %% [markdown]
# ###### 2. Clean the data column by column
# - Ensure that addresses (or other text data) are consistent
# - Eliminate string characters from numeric values
# - Exclude redundant data as appropriate

# %%
# Clean up location data to ensure consistency
data['Location'].replace({'2 Monitors and sub': 'Not Included', 
                          'DFW' : 'Dallas - Fortworth, TX',
                          '84047 Midvale Utah' : 'Midvale, Utah 84047',
                          '08085 swedesboro NJ' : 'Swedesboro, NF 08085'
                         }, inplace=True)

data2['Location'].replace({'2 Monitors and sub': 'Not Included', 
                          'DFW' : 'Dallas - Fortworth, TX',
                          '84047 Midvale Utah' : 'Midvale, Utah 84047',
                          '08085 swedesboro NJ' : 'Swedesboro, NF 08085'
                         }, inplace=True)

# %%
#set(data.Location)
#set(data2.Location)

# %%
# Eliminate string characters from numeric data
data['Price'] = data['Price'].str.replace('NEGOTIATE','.555')
data['Price'] = data['Price'].str.replace('Trade','.666')
data['Price'] = data['Price'].str.replace('SOLD','.777')
data['Price'] = data['Price'].str.replace('You','.111')
data['Price'] = data['Price'].str.replace('$','')
data['Price'] = data['Price'].str.replace('\xa0','')
data['Price'] = data['Price'].str.replace('.U.S','')
data['Price'] = data['Price'].str.replace(',','')
data['Price'] = data['Price'].str.split().str[0]
data['Price'] = data['Price'].str.split('+').str[0]
data['Price'] = data['Price'].astype(float)

data2['Price'] = data2['Price'].str.replace('NEGOTIATE','.555')
data2['Price'] = data2['Price'].str.replace('Trade','.666')
data2['Price'] = data2['Price'].str.replace('SOLD','.777')
data2['Price'] = data2['Price'].str.replace('You','.111')
data2['Price'] = data2['Price'].str.replace('$','')
data2['Price'] = data2['Price'].str.replace('\xa0','')
data2['Price'] = data2['Price'].str.replace('.U.S','')
data2['Price'] = data2['Price'].str.replace(',','')
data2['Price'] = data2['Price'].str.split().str[0]
data2['Price'] = data2['Price'].str.split('+').str[0]
data2['Price'] = data2['Price'].astype(float)

# %%
#set(data.Price)
#set(data2.Price)

# %%
# Exclude redundant rows
NoDupsData = data.drop_duplicates()
NoDupsData2 = data2.drop_duplicates()
NoDupsData
# Out:
#     Condition       Date      ID  \
# 0        used 2017-02-27  119161
# 1        used 2017-02-27  119160
# 2        used 2017-02-27  119159
# 3        used 2017-02-27  119158
# 4    like new 2017-02-27  119157
# 5        used 2017-02-27  119155
# 6        used 2017-02-27  119154
# 7        used 2017-02-27  119153
# 8        used 2017-02-27  119152
# 9        used 2017-02-27  119151
# 10       used 2017-02-27  119150
# 11   like new 2017-02-27  119149
# 12   like new 2017-02-27  119148
# 13   like new 2017-02-27  119147
# 14   like new 2017-02-27  119146
# 15       used 2017-02-27  119143
# 16       used 2017-02-27  119141
# 17   like new 2017-02-27  119139
# 18   like new 2017-02-27  119138
# 19   like new 2017-02-27  119138
# 22   like new 2017-02-27  119133
# 23   like new 2017-02-27  119132
# 24   like new 2017-02-27  119131
# 25   like new 2017-02-27  119131
# 27   like new 2017-02-27  119128
# 28   like new 2017-02-27  119127
# 29   like new 2017-02-27  119127
# 31       used 2017-02-27  119124
# 32       used 2017-02-27  119123
# 33   like new 2017-02-27  119122
# ..        ...        ...     ...
# 433  like new 2017-02-27  118643
# 434  like new 2017-02-27  118642
# 435  like new 2017-02-27  118641
# 436      used 2017-02-27  118640
# 437  like new 2017-02-27  118639
# 438  like new 2017-02-27  118638
# 439      used 2017-02-27  118637
# 440      used 2017-02-27  118636
# 441  like new 2017-02-27  118635
# 442  like new 2017-02-27  118634
# 443  like new 2017-02-27  118633
# 444      used 2017-02-27  118632
# 445      used 2017-02-27  118628
# 446  like new 2017-02-27  118627
# 447  like new 2017-02-27  118626
# 448  like new 2017-02-27  118624
# 449  like new 2017-02-27  118623
# 450  like new 2017-02-27  118622
# 451  like new 2017-02-27  118622
# 452  like new 2017-02-27  118620
# 453      used 2017-02-27  118619
# 454      used 2017-02-27  118618
# 455      used 2017-02-27  118617
# 456  like new 2017-02-27  118615
# 457  like new 2017-02-27  118614
# 458  like new 2017-02-27  118613
# 459  like new 2017-02-27  118612
# 460  like new 2017-02-27  118612
# 461  like new 2017-02-27  118610
# 462  like new 2017-02-27  118609
#
#                                                   Link              Location  \
# 0    https://tradingpost.sweetwater.com/119161-used...       Minneapolis, MN
# 1    https://tradingpost.sweetwater.com/119160-used...        Burlington, VT
# 2    https://tradingpost.sweetwater.com/119159-used...       Minneapolis, MN
# 3    https://tradingpost.sweetwater.com/119158-used...                 07086
# 4    https://tradingpost.sweetwater.com/119157-like...       Fort Wayne,  IN
# 5    https://tradingpost.sweetwater.com/119155-used...                    NH
# 6    https://tradingpost.sweetwater.com/119154-used...                    NH
# 7    https://tradingpost.sweetwater.com/119153-used...                    NH
# 8    https://tradingpost.sweetwater.com/119152-used...                    NH
# 9    https://tradingpost.sweetwater.com/119151-used...                    NH
# 10   https://tradingpost.sweetwater.com/119150-used...                    NH
# 11   https://tradingpost.sweetwater.com/119149-like...              Mesa, AZ
# 12   https://tradingpost.sweetwater.com/119148-like...              Mesa, AZ
# 13   https://tradingpost.sweetwater.com/119147-like...        palm coast, fl
# 14   https://tradingpost.sweetwater.com/119146-like...        palm coast, fl
# 15   https://tradingpost.sweetwater.com/119143-used...         Asheville, NC
# 16   https://tradingpost.sweetwater.com/119141-used...                 93657
# 17   https://tradingpost.sweetwater.com/119139-like...       Orland Park, IL
# 18   https://tradingpost.sweetwater.com/119138-like...          Zachary, LA.
# 19   https://tradingpost.sweetwater.com/119138-like...                   n/a
# 22   https://tradingpost.sweetwater.com/119133-like...               Rex, GA
# 23   https://tradingpost.sweetwater.com/119132-like...                   n/a
# 24   https://tradingpost.sweetwater.com/119131-like...        Alexandria, VA
# 25   https://tradingpost.sweetwater.com/119131-like...                   n/a
# 27   https://tradingpost.sweetwater.com/119128-like...            Irvine, CA
# 28   https://tradingpost.sweetwater.com/119127-like...                 80249
# 29   https://tradingpost.sweetwater.com/119127-like...                   n/a
# 31   https://tradingpost.sweetwater.com/119124-used...  Greater St Louis, MO
# 32   https://tradingpost.sweetwater.com/119123-used...             Australia
# 33   https://tradingpost.sweetwater.com/119122-like...  Greater St Louis, MO
# ..                                                 ...                   ...
# 433  https://tradingpost.sweetwater.com/118643-like...        Fort Wayne, IN
# 434  https://tradingpost.sweetwater.com/118642-like...        Morristown, NJ
# 435  https://tradingpost.sweetwater.com/118641-like...      Philadelphia, PA
# 436  https://tradingpost.sweetwater.com/118640-used...        El Paso, Texas
# 437  https://tradingpost.sweetwater.com/118639-like...           Clinton, IL
# 438  https://tradingpost.sweetwater.com/118638-like...        El Paso, Texas
# 439  https://tradingpost.sweetwater.com/118637-used...           Chicago, IL
# 440  https://tradingpost.sweetwater.com/118636-used...                 60660
# 441  https://tradingpost.sweetwater.com/118635-like...           Chicago, IL
# 442  https://tradingpost.sweetwater.com/118634-like...           Orlando, Fl
# 443  https://tradingpost.sweetwater.com/118633-like...           Orlando, Fl
# 444  https://tradingpost.sweetwater.com/118632-used...           Orlando, Fl
# 445  https://tradingpost.sweetwater.com/118628-used...                 95503
# 446  https://tradingpost.sweetwater.com/118627-like...           Lathrop, CA
# 447  https://tradingpost.sweetwater.com/118626-like...      Philadelphia, PA
# 448  https://tradingpost.sweetwater.com/118624-like...            Muncie, IN
# 449  https://tradingpost.sweetwater.com/118623-like...        Fort Wayne, IN
# 450  https://tradingpost.sweetwater.com/118622-like...       Santa Monica ca
# 451  https://tradingpost.sweetwater.com/118622-like...                   n/a
# 452  https://tradingpost.sweetwater.com/118620-like...         Hollywood, FL
# 453  https://tradingpost.sweetwater.com/118619-used...          South Africa
# 454  https://tradingpost.sweetwater.com/118618-used...         Hollywood, FL
# 455  https://tradingpost.sweetwater.com/118617-used...         Hollywood, FL
# 456  https://tradingpost.sweetwater.com/118615-like...            Boston, MA
# 457  https://tradingpost.sweetwater.com/118614-like...            Austin, TX
# 458  https://tradingpost.sweetwater.com/118613-like...            Boston, MA
# 459  https://tradingpost.sweetwater.com/118612-like...            Boston, MA
# 460  https://tradingpost.sweetwater.com/118612-like...                   n/a
# 461  https://tradingpost.sweetwater.com/118610-like...          San Jose, CA
# 462  https://tradingpost.sweetwater.com/118609-like...          Bay Area, CA
#
#        Price      Source                                              Title
# 0      295.0  Sweetwater                                         tascam 302
# 1     1000.0  Sweetwater                                         eaw la 118
# 2      325.0  Sweetwater                            yamaha mx200 24 channel
# 3     1300.0  Sweetwater                                  soundtracs cm4400
# 4      399.0  Sweetwater                         fender fender blues jr iii
# 5      350.0  Sweetwater                      studer revox b77 reel to reel
# 6      750.0  Sweetwater                      otari reel to reel mx5050 bii
# 7       50.0  Sweetwater                     hosa headphone extension cable
# 8      299.0  Sweetwater                       electro voice  ev re20 re 20
# 9      250.0  Sweetwater                        sennheiser md421 md 421 u 5
# 10     250.0  Sweetwater                        sennheiser md421 md 421 u 5
# 11    1995.0  Sweetwater                                      prism orpheus
# 12    1995.0  Sweetwater                                      prism orpheus
# 13     199.0  Sweetwater                                     mackie cr 1604
# 14     295.0  Sweetwater                                ibanez sr300m  bass
# 15     500.0  Sweetwater                                        yamaha an1x
# 16     750.0  Sweetwater                            panasonic ramsa wr t820
# 17     600.0  Sweetwater                                         yamaha hs8
# 18     525.0  Sweetwater                                   furman p 1800 ar
# 19     525.0  Sweetwater                                   furman p 1800 ar
# 22     500.0  Sweetwater                        universal audio apollo twin
# 23    1395.0  Sweetwater            roland vs 700 digital audio workstation
# 24    1200.0  Sweetwater                           allen &amp; heath qu pac
# 25    1200.0  Sweetwater                           allen &amp; heath qu pac
# 27    1000.0  Sweetwater                           presonus studiolive 1642
# 28    3000.0  Sweetwater                                     soundcraft gb8
# 29    3000.0  Sweetwater                                     soundcraft gb8
# 31     400.0  Sweetwater  mackie hr824 high resolution active studio mon...
# 32    3500.0  Sweetwater                                      eventide h910
# 33    1350.0  Sweetwater                                       focal cms 65
# ..       ...         ...                                                ...
# 433   1100.0  Sweetwater                roland tr 8 tb 3  system 1 plug out
# 434   2500.0  Sweetwater                                       shure scm262
# 435   1450.0  Sweetwater                                            api a2d
# 436   5000.0  Sweetwater                              crane song spider 192
# 437    650.0  Sweetwater                     fender american standard strat
# 438   3100.0  Sweetwater                                           gml 8304
# 439    325.0  Sweetwater                                     carvin trx 218
# 440    775.0  Sweetwater                               rci acrylic drum set
# 441    999.0  Sweetwater                          ev electro voice etx 18sp
# 442   1450.0  Sweetwater                                 prs custom 24 1987
# 443    800.0  Sweetwater              gibson les paul standard 2013 goldtop
# 444    870.0  Sweetwater                gibson les paul standard 1995 black
# 445    500.0  Sweetwater                              yorkville pulse tl315
# 446    500.0  Sweetwater                behringer behringer eurodesk mx9000
# 447   1750.0  Sweetwater                              pioneer cdj 2000 nxs2
# 448   1500.0  Sweetwater                      korg korg trinity pro x v3 88
# 449    800.0  Sweetwater                                       korg krome73
# 450    400.0  Sweetwater                                  mackie cr1604 vlz
# 451    400.0  Sweetwater                                  mackie cr1604 vlz
# 452  10595.0  Sweetwater  fender custom shop stevie ray vaughan lenny  s...
# 453     17.0  Sweetwater                               sound craft si1  vi1
# 454   6995.0  Sweetwater               paul reed smith 1996 santana i model
# 455   3495.0  Sweetwater      martin 1996 eric clapton 00028ec  first year
# 456    150.0  Sweetwater              native instruments traktor kontrol f1
# 457   1100.0  Sweetwater                                   shure ur2beta87c
# 458    450.0  Sweetwater                                    denon mc6000mk2
# 459    480.0  Sweetwater                                         akai max49
# 460    480.0  Sweetwater                                         akai max49
# 461    260.0  Sweetwater             barcus berry 4000xl planar wave system
# 462    770.0  Sweetwater                     beyerdynamic mc 930 stereo set
#
# [397 rows x 8 columns]

# %% [markdown]
# ###### 3. Merge dataframes from separate json files as appropriate
# - Find the intersection of two (or more) sets
# - Compare the intersection with the newer set to find 'New Products'
#     - When found, add the starting date
# - Compare the intersection with the older set to find 'Closed Products'
#     - When found, add the closing date
#     - Compare closing date with starting date to find days on market

# %%
# Create the inner merge of the two dataframes
dataInnerMerge = pd.merge(NoDupsData, NoDupsData2, \
                          on=['ID','Location','Title','Price'],\
                          how='inner')
dataInnerMerge
# Out:
#     Condition_x     Date_x      ID  \
# 0          used 2017-02-27  119161
# 1          used 2017-02-27  119160
# 2          used 2017-02-27  119159
# 3          used 2017-02-27  119158
# 4      like new 2017-02-27  119157
# 5          used 2017-02-27  119155
# 6          used 2017-02-27  119154
# 7          used 2017-02-27  119153
# 8          used 2017-02-27  119152
# 9          used 2017-02-27  119151
# 10         used 2017-02-27  119150
# 11     like new 2017-02-27  119149
# 12     like new 2017-02-27  119148
# 13     like new 2017-02-27  119147
# 14     like new 2017-02-27  119146
# 15         used 2017-02-27  119141
# 16     like new 2017-02-27  119139
# 17     like new 2017-02-27  119133
# 18     like new 2017-02-27  119132
# 19     like new 2017-02-27  119131
# 20     like new 2017-02-27  119131
# 21     like new 2017-02-27  119128
# 22     like new 2017-02-27  119127
# 23     like new 2017-02-27  119127
# 24         used 2017-02-27  119123
# 25     like new 2017-02-27  119121
# 26     like new 2017-02-27  119120
# 27     like new 2017-02-27  119117
# 28     like new 2017-02-27  119116
# 29         used 2017-02-27  119115
# ..          ...        ...     ...
# 343        used 2017-02-27  118667
# 344        used 2017-02-27  118666
# 345    like new 2017-02-27  118665
# 346    like new 2017-02-27  118659
# 347        used 2017-02-27  118658
# 348    like new 2017-02-27  118657
# 349    like new 2017-02-27  118652
# 350        used 2017-02-27  118651
# 351        used 2017-02-27  118648
# 352    like new 2017-02-27  118647
# 353        used 2017-02-27  118646
# 354        used 2017-02-27  118646
# 355    like new 2017-02-27  118644
# 356    like new 2017-02-27  118643
# 357    like new 2017-02-27  118642
# 358    like new 2017-02-27  118641
# 359        used 2017-02-27  118640
# 360    like new 2017-02-27  118639
# 361    like new 2017-02-27  118638
# 362        used 2017-02-27  118637
# 363        used 2017-02-27  118636
# 364    like new 2017-02-27  118635
# 365    like new 2017-02-27  118634
# 366    like new 2017-02-27  118633
# 367        used 2017-02-27  118632
# 368        used 2017-02-27  118628
# 369    like new 2017-02-27  118627
# 370    like new 2017-02-27  118626
# 371    like new 2017-02-27  118624
# 372    like new 2017-02-27  118623
#
#                                                 Link_x            Location  \
# 0    https://tradingpost.sweetwater.com/119161-used...     Minneapolis, MN
# 1    https://tradingpost.sweetwater.com/119160-used...      Burlington, VT
# 2    https://tradingpost.sweetwater.com/119159-used...     Minneapolis, MN
# 3    https://tradingpost.sweetwater.com/119158-used...               07086
# 4    https://tradingpost.sweetwater.com/119157-like...     Fort Wayne,  IN
# 5    https://tradingpost.sweetwater.com/119155-used...                  NH
# 6    https://tradingpost.sweetwater.com/119154-used...                  NH
# 7    https://tradingpost.sweetwater.com/119153-used...                  NH
# 8    https://tradingpost.sweetwater.com/119152-used...                  NH
# 9    https://tradingpost.sweetwater.com/119151-used...                  NH
# 10   https://tradingpost.sweetwater.com/119150-used...                  NH
# 11   https://tradingpost.sweetwater.com/119149-like...            Mesa, AZ
# 12   https://tradingpost.sweetwater.com/119148-like...            Mesa, AZ
# 13   https://tradingpost.sweetwater.com/119147-like...      palm coast, fl
# 14   https://tradingpost.sweetwater.com/119146-like...      palm coast, fl
# 15   https://tradingpost.sweetwater.com/119141-used...               93657
# 16   https://tradingpost.sweetwater.com/119139-like...     Orland Park, IL
# 17   https://tradingpost.sweetwater.com/119133-like...             Rex, GA
# 18   https://tradingpost.sweetwater.com/119132-like...                 n/a
# 19   https://tradingpost.sweetwater.com/119131-like...      Alexandria, VA
# 20   https://tradingpost.sweetwater.com/119131-like...                 n/a
# 21   https://tradingpost.sweetwater.com/119128-like...          Irvine, CA
# 22   https://tradingpost.sweetwater.com/119127-like...               80249
# 23   https://tradingpost.sweetwater.com/119127-like...                 n/a
# 24   https://tradingpost.sweetwater.com/119123-used...           Australia
# 25   https://tradingpost.sweetwater.com/119121-like...        Pittston, PA
# 26   https://tradingpost.sweetwater.com/119120-like...  Puerto Rico U.S.A.
# 27   https://tradingpost.sweetwater.com/119117-like...       Allentown, PA
# 28   https://tradingpost.sweetwater.com/119116-like...                 n/a
# 29   https://tradingpost.sweetwater.com/119115-used...          Irving, TX
# ..                                                 ...                 ...
# 343  https://tradingpost.sweetwater.com/118667-used...              Mbox 2
# 344  https://tradingpost.sweetwater.com/118666-used...        Not Included
# 345  https://tradingpost.sweetwater.com/118665-like...                 n/a
# 346  https://tradingpost.sweetwater.com/118659-like...          Denver, CO
# 347  https://tradingpost.sweetwater.com/118658-used...         Joplin, MO.
# 348  https://tradingpost.sweetwater.com/118657-like...               65810
# 349  https://tradingpost.sweetwater.com/118652-like...                 n/a
# 350  https://tradingpost.sweetwater.com/118651-used...                 n/a
# 351  https://tradingpost.sweetwater.com/118648-used...         Lockport ny
# 352  https://tradingpost.sweetwater.com/118647-like...              Sweden
# 353  https://tradingpost.sweetwater.com/118646-used...        Bay Area, CA
# 354  https://tradingpost.sweetwater.com/118646-used...                 n/a
# 355  https://tradingpost.sweetwater.com/118644-like...            Iola, KS
# 356  https://tradingpost.sweetwater.com/118643-like...      Fort Wayne, IN
# 357  https://tradingpost.sweetwater.com/118642-like...      Morristown, NJ
# 358  https://tradingpost.sweetwater.com/118641-like...    Philadelphia, PA
# 359  https://tradingpost.sweetwater.com/118640-used...      El Paso, Texas
# 360  https://tradingpost.sweetwater.com/118639-like...         Clinton, IL
# 361  https://tradingpost.sweetwater.com/118638-like...      El Paso, Texas
# 362  https://tradingpost.sweetwater.com/118637-used...         Chicago, IL
# 363  https://tradingpost.sweetwater.com/118636-used...               60660
# 364  https://tradingpost.sweetwater.com/118635-like...         Chicago, IL
# 365  https://tradingpost.sweetwater.com/118634-like...         Orlando, Fl
# 366  https://tradingpost.sweetwater.com/118633-like...         Orlando, Fl
# 367  https://tradingpost.sweetwater.com/118632-used...         Orlando, Fl
# 368  https://tradingpost.sweetwater.com/118628-used...               95503
# 369  https://tradingpost.sweetwater.com/118627-like...         Lathrop, CA
# 370  https://tradingpost.sweetwater.com/118626-like...    Philadelphia, PA
# 371  https://tradingpost.sweetwater.com/118624-like...          Muncie, IN
# 372  https://tradingpost.sweetwater.com/118623-like...      Fort Wayne, IN
#
#        Price    Source_x                                              Title  \
# 0      295.0  Sweetwater                                         tascam 302
# 1     1000.0  Sweetwater                                         eaw la 118
# 2      325.0  Sweetwater                            yamaha mx200 24 channel
# 3     1300.0  Sweetwater                                  soundtracs cm4400
# 4      399.0  Sweetwater                         fender fender blues jr iii
# 5      350.0  Sweetwater                      studer revox b77 reel to reel
# 6      750.0  Sweetwater                      otari reel to reel mx5050 bii
# 7       50.0  Sweetwater                     hosa headphone extension cable
# 8      299.0  Sweetwater                       electro voice  ev re20 re 20
# 9      250.0  Sweetwater                        sennheiser md421 md 421 u 5
# 10     250.0  Sweetwater                        sennheiser md421 md 421 u 5
# 11    1995.0  Sweetwater                                      prism orpheus
# 12    1995.0  Sweetwater                                      prism orpheus
# 13     199.0  Sweetwater                                     mackie cr 1604
# 14     295.0  Sweetwater                                ibanez sr300m  bass
# 15     750.0  Sweetwater                            panasonic ramsa wr t820
# 16     600.0  Sweetwater                                         yamaha hs8
# 17     500.0  Sweetwater                        universal audio apollo twin
# 18    1395.0  Sweetwater            roland vs 700 digital audio workstation
# 19    1200.0  Sweetwater                           allen &amp; heath qu pac
# 20    1200.0  Sweetwater                           allen &amp; heath qu pac
# 21    1000.0  Sweetwater                           presonus studiolive 1642
# 22    3000.0  Sweetwater                                     soundcraft gb8
# 23    3000.0  Sweetwater                                     soundcraft gb8
# 24    3500.0  Sweetwater                                      eventide h910
# 25      90.0  Sweetwater            chauvet obey 70 dmx lighting controller
# 26    2199.0  Sweetwater  gibson memphis es 335 figure vintage sunburn 2014
# 27   15500.0  Sweetwater                 fender authentic 59 precision bass
# 28     350.0  Sweetwater        roland a 37 76 key midi keyboard controller
# 29     325.0  Sweetwater  roland ag 5 funny cat 1970s harmonic mover  so...
# ..       ...         ...                                                ...
# 343    100.0  Sweetwater                                  digidesign mbox 2
# 344    150.0  Sweetwater                                  samson reslov 50a
# 345    160.0  Sweetwater                                 blue blue bird mic
# 346    595.0  Sweetwater  waves horizon bundle  lowest price youll proba...
# 347    625.0  Sweetwater                             epiphone prophecy plus
# 348     75.0  Sweetwater                       behringer xeynx 1202fx mixer
# 349    650.0  Sweetwater   fender american standard stratocaster black 1999
# 350   1250.0  Sweetwater       gibson les paul classic custom wine red 2011
# 351    675.0  Sweetwater                                mojave audio ma 200
# 352   5400.0  Sweetwater                       m audio burmester 808 mk iii
# 353    200.0  Sweetwater                                   yorkville ap2020
# 354    200.0  Sweetwater                                   yorkville ap2020
# 355    500.0  Sweetwater                                    vocopro hv 1200
# 356   1100.0  Sweetwater                roland tr 8 tb 3  system 1 plug out
# 357   2500.0  Sweetwater                                       shure scm262
# 358   1450.0  Sweetwater                                            api a2d
# 359   5000.0  Sweetwater                              crane song spider 192
# 360    650.0  Sweetwater                     fender american standard strat
# 361   3100.0  Sweetwater                                           gml 8304
# 362    325.0  Sweetwater                                     carvin trx 218
# 363    775.0  Sweetwater                               rci acrylic drum set
# 364    999.0  Sweetwater                          ev electro voice etx 18sp
# 365   1450.0  Sweetwater                                 prs custom 24 1987
# 366    800.0  Sweetwater              gibson les paul standard 2013 goldtop
# 367    870.0  Sweetwater                gibson les paul standard 1995 black
# 368    500.0  Sweetwater                              yorkville pulse tl315
# 369    500.0  Sweetwater                behringer behringer eurodesk mx9000
# 370   1750.0  Sweetwater                              pioneer cdj 2000 nxs2
# 371   1500.0  Sweetwater                      korg korg trinity pro x v3 88
# 372    800.0  Sweetwater                                       korg krome73
#
#     Condition_y     Date_y                                             Link_y  \
# 0          used 2017-03-01  https://tradingpost.sweetwater.com/119161-used...
# 1          used 2017-03-01  https://tradingpost.sweetwater.com/119160-used...
# 2          used 2017-03-01  https://tradingpost.sweetwater.com/119159-used...
# 3          used 2017-03-01  https://tradingpost.sweetwater.com/119158-used...
# 4      like new 2017-03-01  https://tradingpost.sweetwater.com/119157-like...
# 5          used 2017-03-01  https://tradingpost.sweetwater.com/119155-used...
# 6          used 2017-03-01  https://tradingpost.sweetwater.com/119154-used...
# 7          used 2017-03-01  https://tradingpost.sweetwater.com/119153-used...
# 8          used 2017-03-01  https://tradingpost.sweetwater.com/119152-used...
# 9          used 2017-03-01  https://tradingpost.sweetwater.com/119151-used...
# 10         used 2017-03-01  https://tradingpost.sweetwater.com/119150-used...
# 11     like new 2017-03-01  https://tradingpost.sweetwater.com/119149-like...
# 12     like new 2017-03-01  https://tradingpost.sweetwater.com/119148-like...
# 13     like new 2017-03-01  https://tradingpost.sweetwater.com/119147-like...
# 14     like new 2017-03-01  https://tradingpost.sweetwater.com/119146-like...
# 15         used 2017-03-01  https://tradingpost.sweetwater.com/119141-used...
# 16     like new 2017-03-01  https://tradingpost.sweetwater.com/119139-like...
# 17     like new 2017-03-01  https://tradingpost.sweetwater.com/119133-like...
# 18     like new 2017-03-01  https://tradingpost.sweetwater.com/119132-like...
# 19     like new 2017-03-01  https://tradingpost.sweetwater.com/119131-like...
# 20     like new 2017-03-01  https://tradingpost.sweetwater.com/119131-like...
# 21     like new 2017-03-01  https://tradingpost.sweetwater.com/119128-like...
# 22     like new 2017-03-01  https://tradingpost.sweetwater.com/119127-like...
# 23     like new 2017-03-01  https://tradingpost.sweetwater.com/119127-like...
# 24         used 2017-03-01  https://tradingpost.sweetwater.com/119123-used...
# 25     like new 2017-03-01  https://tradingpost.sweetwater.com/119121-like...
# 26     like new 2017-03-01  https://tradingpost.sweetwater.com/119120-like...
# 27     like new 2017-03-01  https://tradingpost.sweetwater.com/119117-like...
# 28     like new 2017-03-01  https://tradingpost.sweetwater.com/119116-like...
# 29         used 2017-03-01  https://tradingpost.sweetwater.com/119115-used...
# ..          ...        ...                                                ...
# 343        used 2017-03-01  https://tradingpost.sweetwater.com/118667-used...
# 344        used 2017-03-01  https://tradingpost.sweetwater.com/118666-used...
# 345    like new 2017-03-01  https://tradingpost.sweetwater.com/118665-like...
# 346    like new 2017-03-01  https://tradingpost.sweetwater.com/118659-like...
# 347        used 2017-03-01  https://tradingpost.sweetwater.com/118658-used...
# 348    like new 2017-03-01  https://tradingpost.sweetwater.com/118657-like...
# 349    like new 2017-03-01  https://tradingpost.sweetwater.com/118652-like...
# 350        used 2017-03-01  https://tradingpost.sweetwater.com/118651-used...
# 351        used 2017-03-01  https://tradingpost.sweetwater.com/118648-used...
# 352    like new 2017-03-01  https://tradingpost.sweetwater.com/118647-like...
# 353        used 2017-03-01  https://tradingpost.sweetwater.com/118646-used...
# 354        used 2017-03-01  https://tradingpost.sweetwater.com/118646-used...
# 355    like new 2017-03-01  https://tradingpost.sweetwater.com/118644-like...
# 356    like new 2017-03-01  https://tradingpost.sweetwater.com/118643-like...
# 357    like new 2017-03-01  https://tradingpost.sweetwater.com/118642-like...
# 358    like new 2017-03-01  https://tradingpost.sweetwater.com/118641-like...
# 359        used 2017-03-01  https://tradingpost.sweetwater.com/118640-used...
# 360    like new 2017-03-01  https://tradingpost.sweetwater.com/118639-like...
# 361    like new 2017-03-01  https://tradingpost.sweetwater.com/118638-like...
# 362        used 2017-03-01  https://tradingpost.sweetwater.com/118637-used...
# 363        used 2017-03-01  https://tradingpost.sweetwater.com/118636-used...
# 364    like new 2017-03-01  https://tradingpost.sweetwater.com/118635-like...
# 365    like new 2017-03-01  https://tradingpost.sweetwater.com/118634-like...
# 366    like new 2017-03-01  https://tradingpost.sweetwater.com/118633-like...
# 367        used 2017-03-01  https://tradingpost.sweetwater.com/118632-used...
# 368        used 2017-03-01  https://tradingpost.sweetwater.com/118628-used...
# 369    like new 2017-03-01  https://tradingpost.sweetwater.com/118627-like...
# 370    like new 2017-03-01  https://tradingpost.sweetwater.com/118626-like...
# 371    like new 2017-03-01  https://tradingpost.sweetwater.com/118624-like...
# 372    like new 2017-03-01  https://tradingpost.sweetwater.com/118623-like...
#
#        Source_y
# 0    Sweetwater
# 1    Sweetwater
# 2    Sweetwater
# 3    Sweetwater
# 4    Sweetwater
# 5    Sweetwater
# 6    Sweetwater
# 7    Sweetwater
# 8    Sweetwater
# 9    Sweetwater
# 10   Sweetwater
# 11   Sweetwater
# 12   Sweetwater
# 13   Sweetwater
# 14   Sweetwater
# 15   Sweetwater
# 16   Sweetwater
# 17   Sweetwater
# 18   Sweetwater
# 19   Sweetwater
# 20   Sweetwater
# 21   Sweetwater
# 22   Sweetwater
# 23   Sweetwater
# 24   Sweetwater
# 25   Sweetwater
# 26   Sweetwater
# 27   Sweetwater
# 28   Sweetwater
# 29   Sweetwater
# ..          ...
# 343  Sweetwater
# 344  Sweetwater
# 345  Sweetwater
# 346  Sweetwater
# 347  Sweetwater
# 348  Sweetwater
# 349  Sweetwater
# 350  Sweetwater
# 351  Sweetwater
# 352  Sweetwater
# 353  Sweetwater
# 354  Sweetwater
# 355  Sweetwater
# 356  Sweetwater
# 357  Sweetwater
# 358  Sweetwater
# 359  Sweetwater
# 360  Sweetwater
# 361  Sweetwater
# 362  Sweetwater
# 363  Sweetwater
# 364  Sweetwater
# 365  Sweetwater
# 366  Sweetwater
# 367  Sweetwater
# 368  Sweetwater
# 369  Sweetwater
# 370  Sweetwater
# 371  Sweetwater
# 372  Sweetwater
#
# [373 rows x 12 columns]

# %%
# Determine the set of 'new products'
NoDupsData2['key1'] = 1
dataInnerMerge['key2'] = 1
newProducts = pd.merge(NoDupsData2, dataInnerMerge, \
                      on=['ID', 'Title','Location','Price'], \
                      how = 'left')

# Create the associated dataframe
newProducts = newProducts[newProducts.key2 != newProducts.key1]

newProducts
# Add the starting date in the dataframe in which the product is first shown
# Out:
# C:\Users\jbavi\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#     Condition       Date      ID  \
# 0    like new 2017-03-01  119178
# 1    like new 2017-03-01  119177
# 2    like new 2017-03-01  119176
# 3    like new 2017-03-01  119175
# 4        used 2017-03-01  119173
# 5        used 2017-03-01  119172
# 6        used 2017-03-01  119171
# 7    like new 2017-03-01  119170
# 8    like new 2017-03-01  119169
# 9    like new 2017-03-01  119168
# 10        new 2017-03-01  119165
# 11        new 2017-03-01  119165
# 12        new 2017-03-01  119163
# 13       used 2017-03-01  119162
# 29       used 2017-03-01  119143
# 32   like new 2017-03-01  119139
# 41   like new 2017-03-01  119122
# 99       used 2017-03-01  119056
# 290      used 2017-03-01  118802
#
#                                                   Link              Location  \
# 0    https://tradingpost.sweetwater.com/119178-like...           Houston, TX
# 1    https://tradingpost.sweetwater.com/119177-like...           Houston, TX
# 2    https://tradingpost.sweetwater.com/119176-like...       Chula Vista, CA
# 3    https://tradingpost.sweetwater.com/119175-like...        Fort Wayne, IN
# 4    https://tradingpost.sweetwater.com/119173-used...        Fort Wayne, IN
# 5    https://tradingpost.sweetwater.com/119172-used...                   n/a
# 6    https://tradingpost.sweetwater.com/119171-used...       Bonney Lake, Wa
# 7    https://tradingpost.sweetwater.com/119170-like...                Sweden
# 8    https://tradingpost.sweetwater.com/119169-like...           MalmĂ¶, SWE
# 9    https://tradingpost.sweetwater.com/119168-like...     Oklahoma City, Ok
# 10   https://tradingpost.sweetwater.com/119165-new-...                 31322
# 11   https://tradingpost.sweetwater.com/119165-new-...                   n/a
# 12   https://tradingpost.sweetwater.com/119163-new-...                 31322
# 13   https://tradingpost.sweetwater.com/119162-used...           LaPorte, IN
# 29   https://tradingpost.sweetwater.com/119143-used...         Asheville, NC
# 32   https://tradingpost.sweetwater.com/119139-like...                   n/a
# 41   https://tradingpost.sweetwater.com/119122-like...  Greater St Louis, MO
# 99   https://tradingpost.sweetwater.com/119056-used...        Fort Wayne, IN
# 290  https://tradingpost.sweetwater.com/118802-used...                   n/a
#
#          Price      Source                                              Title  \
# 0    18000.000  Sweetwater                     avid pro tools complete studio
# 1     1400.000  Sweetwater   universal audio apollo thunderbolt interface duo
# 2      450.000  Sweetwater                    apogee duet with ios capability
# 3      225.000  Sweetwater  audio technica atw 1101g system 10 digital wir...
# 4      199.000  Sweetwater  hannay (whirlwind wd5) hannay avx 100 whirlwin...
# 5        0.111  Sweetwater                                 wtb: thorens td124
# 6      600.000  Sweetwater                           se electronics gemini ii
# 7     5000.000  Sweetwater                            macaudiolab yamaha m7cl
# 8     1100.000  Sweetwater                                           dpa 4023
# 9      160.000  Sweetwater                                            mxl 770
# 10     250.000  Sweetwater                            audio technica ath m70x
# 11     250.000  Sweetwater                            audio technica ath m70x
# 12     500.000  Sweetwater                   native instruments maschine mkii
# 13    1210.000  Sweetwater                                      yamaha s90 xs
# 29     400.000  Sweetwater                                        yamaha an1x
# 32     600.000  Sweetwater                                         yamaha hs8
# 41    1300.000  Sweetwater                                       focal cms 65
# 99     179.000  Sweetwater                                     hafler pro5000
# 290    499.000  Sweetwater                           allen &amp; heath gl2200
#
#      key1 Condition_x Date_x Link_x Source_x Condition_y Date_y Link_y  \
# 0       1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 1       1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 2       1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 3       1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 4       1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 5       1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 6       1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 7       1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 8       1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 9       1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 10      1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 11      1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 12      1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 13      1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 29      1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 32      1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 41      1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 99      1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
# 290     1         NaN    NaT    NaN      NaN         NaN    NaT    NaN
#
#     Source_y  key2
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
# 5        NaN   NaN
# 6        NaN   NaN
# 7        NaN   NaN
# 8        NaN   NaN
# 9        NaN   NaN
# 10       NaN   NaN
# 11       NaN   NaN
# 12       NaN   NaN
# 13       NaN   NaN
# 29       NaN   NaN
# 32       NaN   NaN
# 41       NaN   NaN
# 99       NaN   NaN
# 290      NaN   NaN

# %%
# Determine the set of 'closed products'
NoDupsData['key1'] = 1
closedProducts = pd.merge(NoDupsData, dataInnerMerge, \
                      on=['ID', 'Title','Location','Price'], \
                      how = 'left')

# Create the associated dataframe
closedProducts = closedProducts[closedProducts.key2 != closedProducts.key1]

# Add the closing date in the dataframe in which the product is last shown


# Find days on market by comparing the starting date with the closing date
# Out:
# C:\Users\jbavi\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# ###### 4. Create visualizations
# - Histogram of Prices
# - Histogram of Days on Market
# - Scatter Diagram of Prices vs Days on Market
# - Pie Chart of New, Like New, Used

# %%
# Create a histogram of Prices
goodPrices = newProducts.Price[newProducts['Price'] > 1.0]
goodPrices = goodPrices[goodPrices < 1500.0]
plt.hist(goodPrices)
plt.title("Product Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

#Temporary Data for Days on Market ... for Scatter Plot Example
scatterData = {'Price': goodPrices,\
               'daysOnMarket' : \
               np.random.randint(1,30,size=len(goodPrices))}
sD = pd.DataFrame(scatterData)

# Create a histogram of Days on Market
plt.hist(sD.daysOnMarket)
plt.title("Days On Market")
plt.xlabel("Days")
plt.ylabel("Frequency")
plt.show()

# Create a Scatter Diagram of Prices vs Days on Market
fig = plt.figure()
ax = fig.add_subplot(111)
x = sD.Price
y = sD.daysOnMarket
ax.scatter(x,y,color='blue')
ax.set_ylim([0,30])
ax.set_xlim([0,1600])

plt.title("Days On Market vs Price")
plt.xlabel("Price")
plt.ylabel("Days On Market")
plt.show()

# Create a Pie Chart of New, Like New, and Used products
colors = ["#E13F29", "#D69A80", "#D63B59"]
# Create a pie chart
plt.pie(
    [newProducts.Condition[newProducts.Condition == 'like new'].count(),\
     newProducts.Condition[newProducts.Condition == 'new'].count(), \
     newProducts.Condition[newProducts.Condition == 'used'].count()],
    labels= ['like_new','new','used'],
    shadow=True,
    # with colors
    colors=colors,
    # with one slide exploded out
    explode=(0.1, 0, 0),
    # with the start angle at 90%
    startangle=90,
    # with the percent listed as a fraction
    autopct='%1.1f%%',
    )

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### 5. Trends from your data
# - Search for specific brands and offer counts for each
# - Search for product types and offer counts for each
# - For each of the above (and other) give counts for day over day or week over week

# %%
# List the products representing specific brands of your choosing
# for each date provided
fenderData = NoDupsData[NoDupsData['Title'].str.contains('fender ')]
yamahaData = NoDupsData[NoDupsData['Title'].str.contains('yamaha ')]
gibsonData = NoDupsData[NoDupsData['Title'].str.contains('gibson ')]
fenderData2 = NoDupsData2[NoDupsData2['Title'].str.contains('fender ')]
yamahaData2 = NoDupsData2[NoDupsData2['Title'].str.contains('yamaha ')]
gibsonData2 = NoDupsData2[NoDupsData2['Title'].str.contains('gibson ')]

# Create a bar chart of products by brand (for the brands chosen)
fenderCount = len(fenderData)
yamahaCount = len(yamahaData)
gibsonCount = len(gibsonData)
fenderCount2 = len(fenderData2)
yamahaCount2 = len(yamahaData2)
gibsonCount2 = len(gibsonData2)

objects = ('Fender','Fender2','', 'Yamaha', 'Yamaha2','', \
           'Gibson', 'Gibson2')
colors = ('green','red','blue','green','red','blue','green','red')
y_pos = np.arange(len(objects))
performance = [fenderCount,fenderCount2,0,yamahaCount,yamahaCount2,\
               0,gibsonCount,gibsonCount2]
fig = plt.figure(figsize=(10,7))
plt.bar(y_pos, performance, align='center',alpha=0.5, color=colors)
plt.xticks(y_pos, objects)
plt.ylabel('Counts')
plt.title('Brands')
 
plt.show()

# List the products of a specific type
guitarData = NoDupsData[NoDupsData['Title'].str.contains('guitar ')]
audioData = NoDupsData[NoDupsData['Title'].str.contains('audio ')]
drumData = NoDupsData[NoDupsData['Title'].str.contains('drum ')]
guitarData2 = NoDupsData2[NoDupsData2['Title'].str.contains('guitar ')]
audioData2 = NoDupsData2[NoDupsData2['Title'].str.contains('audio ')]
drumData2 = NoDupsData2[NoDupsData2['Title'].str.contains('drum ')]


# Create a bar chart of products by specific type
# for each date provided
guitarCount = len(guitarData)
audioCount = len(audioData)
drumCount = len(drumData)
guitarCount2 = len(guitarData2)
audioCount2 = len(audioData2)
drumCount2 = len(drumData2)

objects = ('Guitar','Guitar2','', 'Audio','Audio2','', 'Drum','Drum2')
y_pos = np.arange(len(objects))
performance = [guitarCount,guitarCount2,0,audioCount,audioCount2,\
               0,drumCount,drumCount2]
colors = ('green','red','blue','green','red','blue','green','red') 
plt.bar(y_pos, performance, align='center', alpha=0.5, color=colors)
plt.xticks(y_pos, objects)
plt.ylabel('Counts')
plt.title('Product Type')
 
plt.show()

# %%
fenderData[['Link','Title']]
# Out:
#                                                   Link  \
# 4    https://tradingpost.sweetwater.com/119157-like...
# 36   https://tradingpost.sweetwater.com/119117-like...
# 106  https://tradingpost.sweetwater.com/119097-used...
# 192  https://tradingpost.sweetwater.com/118992-used...
# 206  https://tradingpost.sweetwater.com/118977-used...
# 226  https://tradingpost.sweetwater.com/118949-like...
# 232  https://tradingpost.sweetwater.com/118927-used...
# 269  https://tradingpost.sweetwater.com/118883-used...
# 271  https://tradingpost.sweetwater.com/118881-used...
# 273  https://tradingpost.sweetwater.com/118879-used...
# 312  https://tradingpost.sweetwater.com/118831-used...
# 365  https://tradingpost.sweetwater.com/118764-used...
# 366  https://tradingpost.sweetwater.com/118764-used...
# 377  https://tradingpost.sweetwater.com/118751-like...
# 410  https://tradingpost.sweetwater.com/118682-like...
# 426  https://tradingpost.sweetwater.com/118652-like...
# 437  https://tradingpost.sweetwater.com/118639-like...
# 452  https://tradingpost.sweetwater.com/118620-like...
#
#                                                  Title
# 4                           fender fender blues jr iii
# 36                  fender authentic 59 precision bass
# 106                        fender blues deluxe reissue
# 192                              fender 65 twin reverb
# 206  fender american standard stratocaster 2012 can...
# 226                     fender squier jazz bass squier
# 232                           fender 1957 stratocaster
# 269             fender 1969 twin reverb  blackface mod
# 271    fender 1996 nokie edwards telecaster  prototype
# 273                           fender 1965 stratocaster
# 312                                  fender bassman 10
# 365  fender vintage early 1969 silverface drip edge...
# 366  fender vintage early 1969 silverface drip edge...
# 377                       fender hot rod deluxe reverb
# 410    rare 1983 fender american standard stratocaster
# 426   fender american standard stratocaster black 1999
# 437                     fender american standard strat
# 452  fender custom shop stevie ray vaughan lenny  s...

# %%
drumData[['Link','Title']]
